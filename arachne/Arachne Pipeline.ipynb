# %% [markdown]
# # Arachne Pipeline

# %% [raw]
# This notebook creates a network using Arachne-generated data.

# %% [markdown]
# ## Imports Python Packages Needed in the Pipeline

# %%
import ndex2.client as nc
import json
import pandas as pd
import sys
import jsonschema
import requests
import ndexutil.tsv.tsv2nicecx as t2n
from os.path import isfile, expanduser
from os import listdir

# %% [markdown]
# ### NDEx Connection Function

# %%
def load_tutorial_config(connection_name):
    username = "foo"
    password = None
    config_file = expanduser("~/ndex_tutorial_config.json")
    server = "http://public.ndexbio.org"

    if isfile(config_file):
        file = open(config_file, "r")
        config = json.load(file)
        file.close()
        print(json.dumps(config))
        connections = config.get("connections")
        if connections:
            if connection_name:
                connection = connections.get(connection_name)
                if connection.get("password") and connection.get("username"):
                    if connection.get("server"):
                        server = connection.get("server")
                    username = connection.get("username")
                    password = connection.get("password")
                else:
                    print("Error: " + str(connection_name) + " does not define both username and password")
            else:
                print("Error: " + str(connection_name) + "connection name is not defined")
        else:
            print("Error: " + config_file + " does not define any connections")
    else:
        print("Error: " + config_file + " was not found")

    return server, username, password

# %% [markdown]
# ### MyGene.info Access Functions

# %%
def query(q, tax_id='9606', entrezonly=True):
    if entrezonly:
        r = requests.get('http://mygene.info/v3/query?q='+q+'&species='+tax_id+'&entrezonly=true')
    else:
        r = requests.get('http://mygene.info/v3/query?q='+q+'&species='+tax_id)
    result = r.json()
    result['query'] = q
    return result

# run multiple queries and gather results
def query_list(queries, tax_id='9606', fields='sym'):
    results = []
    for q in queries:
        results.append(query(q, tax_id))
    return results

# use the mygene.info efficient batch query method
# to process multiple identifers in one operation
def query_batch(
        query_string,
        tax_id='9606',
        scopes="symbol, entrezgene, alias, uniprot",
        fields="symbol, entrezgene"):
    data = {'species': tax_id,
            'scopes': scopes,
            'fields': fields,
            'q': query_string}
    r = requests.post('http://mygene.info/v3/query', data)
    json = r.json()
    return json

# --------------------------------------------------
#
#  translation methods
#
# --------------------------------------------------

# return:
# 1. a dictionary mapping identifiers in input_ids
# to identifiers types in scopes. When there are ambiguous
# mappings, the highest ranked mapping is chosen and the
# others are placed in an "alternatives" attribute.
# 2. a list of unmapped input_ids
#
# The mygene.info search is limited to the identifier types in scopes.
#
# The results are limited to the species specified by tax_id.

# Optionally, prefix_map may be set to a dictionary mapping
# identifier types to prefixes to prepend to mapped ids, e.g. <prefix>:<id>
#
def get_identifier_map(
        input_ids,
        scopes=["symbol", "entrezgene", "uniprot"],
        field ="entrezgene",
        tax_id='9606',
        prefix = "ncbigene"):
    query_string = ", ".join(input_ids)
    scope_string = ", ".join(scopes)
    query_results = query_batch(
        query_string,
        scopes=scope_string,
        fields=field,
        tax_id=tax_id)

    map = {}
    for result in query_results:
        # print(json.dumps(result))
        output_id = result.get(field)
        input_id = result.get("query")
        if output_id:
            mapping = map.get(input_id)
            if mapping:
                # if there is already a mapping, 
                # we test to see the new mapping
                # has a better score
                if mapping.get("_score") < result.get("_score"):
                    map[input_id] = result
            else:
                map[input_id] = result

    # make output map, add prefixes
    output_map = {}
    for input_id, mapping in map.items():
        output_map[input_id] = prefix + ":" + str(mapping.get(field))
    
    # scan query results and populate unmmaped
    unmapped = []
    for result in query_results:
        input_id = result.get("query")
        if not output_map.get(input_id):
            unmapped.append(input_id)
    unmapped = list(set(unmapped))    
    return output_map, unmapped

# %% [markdown]
# ### Set variables
# Note: The load_tutorial_config() function uses a file in the user's home directory (**~/ndex_tutorial_config.json**).  A sample json file is included in the root of this project (also named "ndex_tutorial_config.json").  Edit this file and copy it to your user home directory.  Alternatively you can just use the hardcoded variables below.

# %%
my_server, my_username, my_password = load_tutorial_config("main")
# alternatively, edit and uncomment these lines to set the connection parameters manually
#my_server = "public.ndexbio.org"
#my_username = 'username'
#my_password = 'password'

if 'dev.ndexbio.org' in my_server:
    cytoscape_visual_properties_template_id = 'c7075eb1-231e-11e8-894b-525400c25d22' # DEV
else:
    cytoscape_visual_properties_template_id = '06afeea7-2e04-11e8-b939-0ac135e8bacf' # PUBLIC

my_ndex=nc.Ndex2(my_server, my_username, my_password)
print(my_server)
print(my_username)
print(my_password)
# Out:
# {"connections": {"main": {"username": "drh", "password": "drh"}}}
# http://public.ndexbio.org
# drh
# drh

# %% [markdown]
# ### Set load plan
# Note: To see the field mapping (load plan) open **arachne_load_plan.json**. This json file resides in the same directory as this notebook

# %%
path_to_load_plan = 'load_plan.json'
load_plan = None
with open(path_to_load_plan, 'r') as lp:
    load_plan = json.load(lp)

# %% [markdown]
# ### Process Arachne networks

# %%
def process_arachne_networks(load_plan):
    print('starting...')
    for file in listdir("data"):
        if file.endswith(".txt"):   
            print("processing " + file)
            process_arachne_network(load_plan, "data/" + file)
    print('finished...')
        
def process_arachne_network(load_plan, file):
    # @CONTEXT is set from the load plan
    with open(file, 'r') as tsvfile:
        header = [h.strip() for h in tsvfile.readline().split('\t')]
        df = pd.read_csv(
            tsvfile, 
            delimiter='\t', 
            na_filter=False, 
            engine='python', names=header)
    
    # ncbigene symbols are prefixed
    # create translation map for gene symbols
    node_identifiers = list(set(df["Gene1"].tolist() + df["Gene2"].tolist()))
    print(str(len(node_identifiers)) + " node_identifiers")
    identifier_map, unmapped_identifiers = get_identifier_map(
        node_identifiers,
        scopes = ["symbol", "alias"],
        field = "entrezgene",
        tax_id='9606',
        prefix = "ncbigene")    
    print(json.dumps(unmapped_identifiers))
    print(str(len(identifier_map.keys())) + " map entries")
    
    for input_id, output_id in identifier_map.items():
        print(input_id + " -> " + output_id)
    
    # add columns Rep1 and Rep2 and translate Gene1 and Gene2
    df['Rep1'] = df['Gene1'].apply(lambda x: identifier_map.get(x)) # if identifier_map.get(x) else x)
    df['Rep2'] = df['Gene2'].apply(lambda x: identifier_map.get(x)) # if identifier_map.get(x) else x)
    
    print(df)

    # if the represents field is empty, substitute the gene name
#    df['Rep1'].replace('', df['Gene1'], inplace=True)
#    df['Rep2'].replace('', df['Gene2'], inplace=True)

#def convert_pandas_to_nice_cx_with_load_plan(pandas_dataframe, load_plan, max_rows=None,
#                                            name=None, description=None,
#                                            network_attributes=None, provenance=None):
#    network = t2n.convert_pandas_to_nice_cx_with_load_plan(df, load_plan)

#    network.set_network_attribute("organism", "Human, 9606, Homo sapiens")
#    network.union_node_attributes('alias', 'alias2', 'alias')

#    network.apply_template(username=my_username, password=my_password, server=my_server,
#                           uuid=cytoscape_visual_properties_template_id)
#    message = network.upload_to(my_server, my_username, my_password)

# %%
process_arachne_networks(load_plan)
# Out:
# starting...
# processing BreastCancerMCF7-CMAP.txt
# 9571 node_identifiers
# ["LOC57399", "LOC100129648", "8-Sep", "LOC100272228"]
# 996 map entries
# ADCY9 -> ncbigene:115
# RBBP9 -> ncbigene:10741
# ETS2 -> ncbigene:2114
# RIMS1 -> ncbigene:22999
# MFF -> ncbigene:56947
# PSMC3IP -> ncbigene:29893
# RAF1 -> ncbigene:5894
# PLTP -> ncbigene:5360
# SDF2 -> ncbigene:6388
# VAPB -> ncbigene:9217
# TAF12 -> ncbigene:6883
# FAM190B -> ncbigene:54462
# SOD2 -> ncbigene:6648
# HIST1H1T -> ncbigene:3010
# AP1S1 -> ncbigene:1174
# STK3 -> ncbigene:6788
# KLHDC10 -> ncbigene:23008
# INTS5 -> ncbigene:80789
# C19orf56 -> ncbigene:51398
# KIAA1462 -> ncbigene:57608
# PPP2CA -> ncbigene:5515
# CXorf48 -> ncbigene:54967
# PTOV1 -> ncbigene:53635
# VNN2 -> ncbigene:8875
# RPS2 -> ncbigene:6187
# CD22 -> ncbigene:933
# CDKN2D -> ncbigene:1032
# SGPL1 -> ncbigene:8879
# MRP63 -> ncbigene:78988
# ATG16L1 -> ncbigene:55054
# ANXA6 -> ncbigene:309
# VAMP4 -> ncbigene:8674
# CSNK1G1 -> ncbigene:53944
# TRPC4 -> ncbigene:7223
# VHL -> ncbigene:7428
# MCCC1 -> ncbigene:56922
# PER3 -> ncbigene:8863
# SMAD4 -> ncbigene:4089
# C6orf162 -> ncbigene:57150
# HIST1H4F -> ncbigene:8361
# PSG1 -> ncbigene:5669
# ANO2 -> ncbigene:57101
# TGFB1I1 -> ncbigene:7041
# B4GALT3 -> ncbigene:8703
# MCF2L2 -> ncbigene:23101
# ACAD10 -> ncbigene:80724
# YWHAZ -> ncbigene:7534
# GALNT6 -> ncbigene:11226
# C21orf62 -> ncbigene:56245
# GRIN2A -> ncbigene:2903
# OXT -> ncbigene:5020
# EIF3B -> ncbigene:8662
# SERPIND1 -> ncbigene:3053
# OMP -> ncbigene:4975
# SH3BGRL -> ncbigene:6451
# CIR1 -> ncbigene:9541
# BCAP29 -> ncbigene:55973
# WAC -> ncbigene:51322
# ZNF384 -> ncbigene:171017
# MAPT -> ncbigene:4137
# GNG4 -> ncbigene:2786
# ROR2 -> ncbigene:4920
# MTL5 -> ncbigene:9633
# RAB11FIP2 -> ncbigene:22841
# BIN2 -> ncbigene:51411
# FOXC1 -> ncbigene:2296
# RCOR1 -> ncbigene:23186
# DBF4 -> ncbigene:10926
# TXLNA -> ncbigene:200081
# PDE4A -> ncbigene:5141
# MST1R -> ncbigene:4486
# RACGAP1 -> ncbigene:29127
# UBA52 -> ncbigene:7311
# HEYL -> ncbigene:26508
# MYO1E -> ncbigene:4643
# HLA-A -> ncbigene:3105
# SPRR2B -> ncbigene:6701
# POLR2L -> ncbigene:5441
# SMG7 -> ncbigene:9887
# PDGFD -> ncbigene:80310
# IFNAR2 -> ncbigene:3455
# C9orf91 -> ncbigene:203197
# NBR1 -> ncbigene:4077
# SHANK2 -> ncbigene:22941
# TRAPPC4 -> ncbigene:51399
# TRAPPC10 -> ncbigene:7109
# NDUFB1 -> ncbigene:4707
# HSPB1 -> ncbigene:3315
# RHOH -> ncbigene:399
# GIT1 -> ncbigene:28964
# KIR2DL4 -> ncbigene:3805
# GGNBP2 -> ncbigene:79893
# SERPINA1 -> ncbigene:5265
# CCR4 -> ncbigene:1233
# CYP4A22 -> ncbigene:284541
# NDUFA8 -> ncbigene:4702
# KLRD1 -> ncbigene:3824
# PIGP -> ncbigene:51227
# KCNA3 -> ncbigene:3738
# MYOM1 -> ncbigene:8736
# MAPK9 -> ncbigene:5601
# SLC25A4 -> ncbigene:291
# CCDC85B -> ncbigene:11007
# DCAF8 -> ncbigene:50717
# POLR2A -> ncbigene:5430
# KCNE2 -> ncbigene:9992
# PPAT -> ncbigene:5471
# INPP1 -> ncbigene:3628
# CCKAR -> ncbigene:886
# NCK2 -> ncbigene:8440
# RASAL1 -> ncbigene:8437
# TNFSF4 -> ncbigene:7292
# ANXA10 -> ncbigene:11199
# PAIP1 -> ncbigene:10605
# POU6F1 -> ncbigene:5463
# RAB7L1 -> ncbigene:8934
# ZNF710 -> ncbigene:374655
# ZMYM1 -> ncbigene:79830
# HYOU1 -> ncbigene:10525
# TG -> ncbigene:7038
# CSNK1G3 -> ncbigene:1456
# CLPB -> ncbigene:81570
# PHF10 -> ncbigene:55274
# DNMT3A -> ncbigene:1788
# MMP7 -> ncbigene:4316
# HOXD9 -> ncbigene:3235
# MLF1 -> ncbigene:4291
# AMHR2 -> ncbigene:269
# KIAA0195 -> ncbigene:9772
# AP4S1 -> ncbigene:11154
# MTM1 -> ncbigene:4534
# DFFA -> ncbigene:1676
# UBA3 -> ncbigene:9039
# B4GALT5 -> ncbigene:9334
# CDSN -> ncbigene:1041
# ERN1 -> ncbigene:2081
# MBP -> ncbigene:4155
# TMC7 -> ncbigene:79905
# TCEAL2 -> ncbigene:140597
# PRPF19 -> ncbigene:27339
# RASGRP2 -> ncbigene:10235
# RPH3A -> ncbigene:22895
# MPP2 -> ncbigene:4355
# INCENP -> ncbigene:3619
# CNNM3 -> ncbigene:26505
# PKP4 -> ncbigene:8502
# MICALL2 -> ncbigene:79778
# CEP97 -> ncbigene:79598
# MRPL13 -> ncbigene:28998
# PISD -> ncbigene:23761
# PHOX2B -> ncbigene:8929
# YAF2 -> ncbigene:10138
# CECR1 -> ncbigene:51816
# MAP3K3 -> ncbigene:4215
# TROVE2 -> ncbigene:6738
# PCDHGA3 -> ncbigene:56112
# RAX -> ncbigene:30062
# SYN1 -> ncbigene:6853
# GTF3C4 -> ncbigene:9329
# GBE1 -> ncbigene:2632
# CACYBP -> ncbigene:27101
# RPL39 -> ncbigene:6170
# SARS2 -> ncbigene:54938
# TECR -> ncbigene:9524
# CSDE1 -> ncbigene:7812
# ANKRD12 -> ncbigene:23253
# C12orf11 -> ncbigene:55726
# OSBP2 -> ncbigene:23762
# PCDHGA1 -> ncbigene:56114
# MIOS -> ncbigene:54468
# KCNJ13 -> ncbigene:3769
# EHF -> ncbigene:26298
# BTK -> ncbigene:695
# HPGD -> ncbigene:3248
# PRKRIR -> ncbigene:5612
# DCPS -> ncbigene:28960
# CHM -> ncbigene:1121
# LMO1 -> ncbigene:4004
# KIAA0226 -> ncbigene:9711
# GALNT8 -> ncbigene:26290
# GDF5 -> ncbigene:8200
# ALDOC -> ncbigene:230
# PCMTD2 -> ncbigene:55251
# PRCC -> ncbigene:5546
# SERPINA7 -> ncbigene:6906
# SMG1 -> ncbigene:23049
# C1orf103 -> ncbigene:55791
# GTDC1 -> ncbigene:79712
# MAPRE1 -> ncbigene:22919
# AGBL3 -> ncbigene:340351
# HOXB9 -> ncbigene:3219
# KIF18A -> ncbigene:81930
# ZNF167 -> ncbigene:55888
# SDCBP -> ncbigene:6386
# SRSF11 -> ncbigene:9295
# AMOT -> ncbigene:154796
# PMVK -> ncbigene:10654
# SEMA4D -> ncbigene:10507
# LYRM2 -> ncbigene:57226
# EIF1B -> ncbigene:10289
# TRAM2 -> ncbigene:9697
# PRKAA2 -> ncbigene:5563
# RPS6KA5 -> ncbigene:9252
# HNRNPA2B1 -> ncbigene:3181
# RECQL -> ncbigene:5965
# CYTH2 -> ncbigene:9266
# MAPK11 -> ncbigene:5600
# NR2F2 -> ncbigene:7026
# PRPF4B -> ncbigene:8899
# PPP1R3A -> ncbigene:5506
# ZXDB -> ncbigene:158586
# SOX11 -> ncbigene:6664
# NUSAP1 -> ncbigene:51203
# PYROXD1 -> ncbigene:79912
# ODC1 -> ncbigene:4953
# LRP6 -> ncbigene:4040
# GPD1L -> ncbigene:23171
# PTMA -> ncbigene:5757
# RAB28 -> ncbigene:9364
# P2RY1 -> ncbigene:5028
# ZNF668 -> ncbigene:79759
# GMNN -> ncbigene:51053
# HSDL2 -> ncbigene:84263
# ACVR1 -> ncbigene:90
# LMBR1L -> ncbigene:55716
# GSS -> ncbigene:2937
# KLF3 -> ncbigene:51274
# PPL -> ncbigene:5493
# GLUL -> ncbigene:2752
# CRYAA -> ncbigene:1409
# VNN1 -> ncbigene:8876
# GLI3 -> ncbigene:2737
# HERC1 -> ncbigene:8925
# IKZF2 -> ncbigene:22807
# CPA4 -> ncbigene:51200
# ACE -> ncbigene:1636
# ATP6V1G1 -> ncbigene:9550
# DDX28 -> ncbigene:55794
# RABAC1 -> ncbigene:10567
# PBK -> ncbigene:55872
# ACADM -> ncbigene:34
# ISOC2 -> ncbigene:79763
# WDR55 -> ncbigene:54853
# TUB -> ncbigene:7275
# WBP4 -> ncbigene:11193
# RAPGEF2 -> ncbigene:9693
# METTL1 -> ncbigene:4234
# KAZ -> ncbigene:23254
# PAOX -> ncbigene:196743
# UCP1 -> ncbigene:7350
# SP140L -> ncbigene:93349
# STX16 -> ncbigene:8675
# KLRB1 -> ncbigene:3820
# GIPC2 -> ncbigene:54810
# RIT1 -> ncbigene:6016
# MINA -> ncbigene:84864
# AHR -> ncbigene:196
# ID3 -> ncbigene:3399
# ADSL -> ncbigene:158
# ELOVL5 -> ncbigene:60481
# HCLS1 -> ncbigene:3059
# C13orf34 -> ncbigene:79866
# SOX10 -> ncbigene:6663
# AKTIP -> ncbigene:64400
# RUFY3 -> ncbigene:22902
# BTC -> ncbigene:685
# BEST1 -> ncbigene:7439
# IL1RAP -> ncbigene:3556
# TPSAB1 -> ncbigene:7177
# LAMA5 -> ncbigene:3911
# ASXL2 -> ncbigene:55252
# EXOG -> ncbigene:9941
# XCL1 -> ncbigene:6375
# C1orf105 -> ncbigene:92346
# EZH2 -> ncbigene:2146
# APBA3 -> ncbigene:9546
# ABHD2 -> ncbigene:11057
# CASP1 -> ncbigene:834
# MAD2L1BP -> ncbigene:9587
# PLCG1 -> ncbigene:5335
# FAM76A -> ncbigene:199870
# GBX2 -> ncbigene:2637
# FTSJ2 -> ncbigene:29960
# DNAH7 -> ncbigene:56171
# HSD17B10 -> ncbigene:3028
# TMEM110 -> ncbigene:375346
# RNH1 -> ncbigene:6050
# NPEPPS -> ncbigene:9520
# FASTKD3 -> ncbigene:79072
# ALLC -> ncbigene:55821
# KLRK1 -> ncbigene:22914
# PAPOLA -> ncbigene:10914
# KCNA6 -> ncbigene:3742
# POLR2F -> ncbigene:5435
# SIRT4 -> ncbigene:23409
# FKBP9 -> ncbigene:11328
# TLX2 -> ncbigene:3196
# LGALS3 -> ncbigene:3958
# METTL5 -> ncbigene:29081
# RAB23 -> ncbigene:51715
# SCTR -> ncbigene:6344
# C5orf13 -> ncbigene:9315
# C10orf10 -> ncbigene:11067
# PCK1 -> ncbigene:5105
# SSB -> ncbigene:6741
# RPL14 -> ncbigene:9045
# PCYT1B -> ncbigene:9468
# LASP1 -> ncbigene:3927
# RBM5 -> ncbigene:10181
# IKBKAP -> ncbigene:8518
# SLC24A2 -> ncbigene:25769
# FABP6 -> ncbigene:2172
# DDR2 -> ncbigene:4921
# HRAS -> ncbigene:3265
# TGIF1 -> ncbigene:7050
# JRKL -> ncbigene:8690
# SR140 -> ncbigene:23350
# APEX2 -> ncbigene:27301
# ZNF323 -> ncbigene:64288
# DPF3 -> ncbigene:8110
# RBM34 -> ncbigene:23029
# DLX2 -> ncbigene:1746
# SELP -> ncbigene:6403
# CREBZF -> ncbigene:58487
# TRAF3IP3 -> ncbigene:80342
# HHEX -> ncbigene:3087
# ZNF426 -> ncbigene:79088
# FGD1 -> ncbigene:2245
# OIP5 -> ncbigene:11339
# GALNT2 -> ncbigene:2590
# CADPS2 -> ncbigene:93664
# ADAMTS5 -> ncbigene:11096
# PCDHA9 -> ncbigene:9752
# TBX19 -> ncbigene:9095
# PYGM -> ncbigene:5837
# PIGO -> ncbigene:84720
# ROBO3 -> ncbigene:64221
# ABCG5 -> ncbigene:64240
# LGALS4 -> ncbigene:3960
# EVX1 -> ncbigene:2128
# CBS -> ncbigene:875
# SAR1A -> ncbigene:56681
# MPHOSPH10 -> ncbigene:10199
# FAM149A -> ncbigene:25854
# UTP20 -> ncbigene:27340
# MED1 -> ncbigene:5469
# AQP4 -> ncbigene:361
# UCK2 -> ncbigene:7371
# SLC14A2 -> ncbigene:8170
# ZNF415 -> ncbigene:55786
# RECK -> ncbigene:8434
# C16orf45 -> ncbigene:89927
# MAX -> ncbigene:4149
# SLC35A2 -> ncbigene:7355
# TM4SF5 -> ncbigene:9032
# MAP1A -> ncbigene:4130
# EIF4ENIF1 -> ncbigene:56478
# RGL1 -> ncbigene:23179
# CD9 -> ncbigene:928
# NT5C2 -> ncbigene:22978
# TFAP2A -> ncbigene:7020
# CDR2L -> ncbigene:30850
# FRS3 -> ncbigene:10817
# FAM131A -> ncbigene:131408
# SLC22A6 -> ncbigene:9356
# ATP11A -> ncbigene:23250
# MYOD1 -> ncbigene:4654
# KIAA1967 -> ncbigene:57805
# CLSTN1 -> ncbigene:22883
# HJURP -> ncbigene:55355
# CASP2 -> ncbigene:835
# PRKRIP1 -> ncbigene:79706
# PMPCA -> ncbigene:23203
# GPR44 -> ncbigene:11251
# ATP1A3 -> ncbigene:478
# PRKD2 -> ncbigene:25865
# B3GALT2 -> ncbigene:8707
# ISOC1 -> ncbigene:51015
# TBC1D4 -> ncbigene:9882
# OR11A1 -> ncbigene:26531
# DCTPP1 -> ncbigene:79077
# GTF2F1 -> ncbigene:2962
# ITGB3 -> ncbigene:3690
# ZNF274 -> ncbigene:10782
# GRIA3 -> ncbigene:2892
# KCNH2 -> ncbigene:3757
# RAB2A -> ncbigene:5862
# ZFHX3 -> ncbigene:463
# SLC22A4 -> ncbigene:6583
# AKAP5 -> ncbigene:9495
# EIF2B2 -> ncbigene:8892
# RTN4 -> ncbigene:57142
# CNDP2 -> ncbigene:55748
# C7orf28B -> ncbigene:221960
# CUTA -> ncbigene:51596
# NUP43 -> ncbigene:348995
# ATXN1 -> ncbigene:6310
# PNMA2 -> ncbigene:10687
# CBR4 -> ncbigene:84869
# UBE2M -> ncbigene:9040
# NECAP2 -> ncbigene:55707
# CNOT4 -> ncbigene:4850
# TOMM70A -> ncbigene:9868
# PAK7 -> ncbigene:57144
# ACTN1 -> ncbigene:87
# SILV -> ncbigene:6490
# RALYL -> ncbigene:138046
# GEMIN4 -> ncbigene:50628
# EYA1 -> ncbigene:2138
# PSMD8 -> ncbigene:5714
# FOXL2 -> ncbigene:668
# PPP1R2P9 -> ncbigene:80316
# POP4 -> ncbigene:10775
# GNAO1 -> ncbigene:2775
# MLANA -> ncbigene:2315
# MARCO -> ncbigene:8685
# UFSP2 -> ncbigene:55325
# UBE2H -> ncbigene:7328
# RGS20 -> ncbigene:8601
# HEBP1 -> ncbigene:50865
# WDR41 -> ncbigene:55255
# PINK1 -> ncbigene:65018
# CHMP4A -> ncbigene:29082
# TMPRSS11D -> ncbigene:9407
# MSRB2 -> ncbigene:22921
# EPM2AIP1 -> ncbigene:9852
# ECE1 -> ncbigene:1889
# UBC -> ncbigene:7316
# ZBTB6 -> ncbigene:10773
# NME4 -> ncbigene:4833
# FBXO41 -> ncbigene:150726
# HIST1H2AM -> ncbigene:8336
# CHRNA5 -> ncbigene:1138
# ZNF337 -> ncbigene:26152
# TP53BP2 -> ncbigene:7159
# TIE1 -> ncbigene:7075
# HNF4G -> ncbigene:3174
# TUBB2B -> ncbigene:347733
# SEC31A -> ncbigene:22872
# C20orf111 -> ncbigene:51526
# PRKG2 -> ncbigene:5593
# MAP3K10 -> ncbigene:4294
# ARFGEF1 -> ncbigene:10565
# PKIA -> ncbigene:5569
# CCNT1 -> ncbigene:904
# POLR2J2 -> ncbigene:246721
# CTBP1 -> ncbigene:1487
# BTBD3 -> ncbigene:22903
# UNC5B -> ncbigene:219699
# ELOVL6 -> ncbigene:79071
# E2F5 -> ncbigene:1875
# ZFP106 -> ncbigene:64397
# BGN -> ncbigene:633
# CYP51A1 -> ncbigene:1595
# ZNF217 -> ncbigene:7764
# TICAM1 -> ncbigene:148022
# PLD1 -> ncbigene:5337
# ITGAL -> ncbigene:3683
# CRISP2 -> ncbigene:7180
# NCSTN -> ncbigene:23385
# TRIM36 -> ncbigene:55521
# LAMA3 -> ncbigene:3909
# PAXIP1 -> ncbigene:22976
# BCHE -> ncbigene:590
# ELN -> ncbigene:2006
# KIAA0284 -> ncbigene:283638
# PLIN1 -> ncbigene:5346
# OSGEPL1 -> ncbigene:64172
# LACTB2 -> ncbigene:51110
# SIRT3 -> ncbigene:23410
# SPRR1B -> ncbigene:6699
# INPP5B -> ncbigene:3633
# SMS -> ncbigene:6611
# NUBP1 -> ncbigene:4682
# MUC5B -> ncbigene:727897
# SRRT -> ncbigene:51593
# ZDHHC18 -> ncbigene:84243
# ALOXE3 -> ncbigene:59344
# PFDN1 -> ncbigene:5201
# LCMT2 -> ncbigene:9836
# PLCB2 -> ncbigene:5330
# SERINC5 -> ncbigene:256987
# MAZ -> ncbigene:4150
# NADK -> ncbigene:65220
# BIK -> ncbigene:638
# ASXL1 -> ncbigene:171023
# ATP6V0C -> ncbigene:527
# ZNF419 -> ncbigene:79744
# BCAM -> ncbigene:4059
# DPP4 -> ncbigene:1803
# AKR1B1 -> ncbigene:231
# CLK4 -> ncbigene:57396
# CDC42SE1 -> ncbigene:56882
# DHX34 -> ncbigene:9704
# EIF2S2 -> ncbigene:8894
# SPAG6 -> ncbigene:9576
# SMAD9 -> ncbigene:4093
# MED12 -> ncbigene:9968
# MFSD5 -> ncbigene:84975
# ATOH1 -> ncbigene:474
# DOLPP1 -> ncbigene:57171
# MNDA -> ncbigene:4332
# LILRB4 -> ncbigene:11006
# DDRGK1 -> ncbigene:65992
# MPDU1 -> ncbigene:9526
# PTK6 -> ncbigene:5753
# HNRPDL -> ncbigene:9987
# SOX12 -> ncbigene:6666
# CALM1 -> ncbigene:801
# C3orf63 -> ncbigene:23272
# DNAJC11 -> ncbigene:55735
# LPCAT1 -> ncbigene:79888
# KLK5 -> ncbigene:25818
# SNX2 -> ncbigene:6643
# KCNG2 -> ncbigene:26251
# C4orf27 -> ncbigene:54969
# NTSR2 -> ncbigene:23620
# SIRPA -> ncbigene:140885
# UBAP2L -> ncbigene:9898
# DUSP1 -> ncbigene:1843
# CSAD -> ncbigene:51380
# KLC1 -> ncbigene:3831
# MRFAP1L1 -> ncbigene:114932
# RPRD1A -> ncbigene:55197
# WWP2 -> ncbigene:11060
# PSMD13 -> ncbigene:5719
# SLIT2 -> ncbigene:9353
# KCNJ8 -> ncbigene:3764
# CTNNA3 -> ncbigene:29119
# RHBDD3 -> ncbigene:25807
# PXN -> ncbigene:5829
# PVRL3 -> ncbigene:100506555
# PARVA -> ncbigene:55742
# TWIST1 -> ncbigene:7291
# GMIP -> ncbigene:51291
# NFKB2 -> ncbigene:4791
# CYLD -> ncbigene:1540
# SCN8A -> ncbigene:6334
# DFFB -> ncbigene:1677
# RPL23 -> ncbigene:9349
# EPS8L1 -> ncbigene:54869
# ABI2 -> ncbigene:10152
# FLII -> ncbigene:2314
# MATN1 -> ncbigene:4146
# TOMM34 -> ncbigene:10953
# HABP4 -> ncbigene:22927
# EML2 -> ncbigene:24139
# KCNA2 -> ncbigene:3737
# CLPP -> ncbigene:8192
# RAPGEF5 -> ncbigene:9771
# JTB -> ncbigene:10899
# ZNF207 -> ncbigene:7756
# SMURF1 -> ncbigene:57154
# TNFRSF1A -> ncbigene:7132
# TRIM14 -> ncbigene:9830
# ITGB5 -> ncbigene:3693
# GPR56 -> ncbigene:9289
# ENPP4 -> ncbigene:22875
# ULK1 -> ncbigene:8408
# NDRG2 -> ncbigene:57447
# TUBB2C -> ncbigene:10383
# TRIM28 -> ncbigene:10155
# ATP5F1 -> ncbigene:515
# RUVBL1 -> ncbigene:8607
# MYOF -> ncbigene:26509
# ATF3 -> ncbigene:467
# EIF1AX -> ncbigene:1964
# GABRB3 -> ncbigene:2562
# SCGB2A2 -> ncbigene:4250
# ZNF611 -> ncbigene:81856
# JAK3 -> ncbigene:3718
# PADI2 -> ncbigene:11240
# NXF3 -> ncbigene:56000
# SNF8 -> ncbigene:11267
# STAB2 -> ncbigene:55576
# CRNKL1 -> ncbigene:51340
# CD180 -> ncbigene:4064
# PTN -> ncbigene:5764
# PLAU -> ncbigene:5328
# ATOX1 -> ncbigene:475
# APOC3 -> ncbigene:345
# CDC23 -> ncbigene:8697
# DNTT -> ncbigene:1791
# MMP11 -> ncbigene:4320
# PRDM9 -> ncbigene:56979
# PODXL -> ncbigene:5420
# CNBP -> ncbigene:7555
# RANBP3 -> ncbigene:8498
# PPIC -> ncbigene:5480
# PLXNA2 -> ncbigene:5362
# PJA2 -> ncbigene:9867
# IAPP -> ncbigene:3375
# CCDC53 -> ncbigene:51019
# ABCC8 -> ncbigene:6833
# PAX9 -> ncbigene:5083
# LAD1 -> ncbigene:3898
# KRT20 -> ncbigene:54474
# SOX1 -> ncbigene:6656
# MBIP -> ncbigene:51562
# TPM4 -> ncbigene:7171
# FLJ20712 -> ncbigene:55025
# THRA -> ncbigene:7067
# MLXIPL -> ncbigene:51085
# CDT1 -> ncbigene:81620
# CHRNA1 -> ncbigene:1134
# PRDX6 -> ncbigene:9588
# MLST8 -> ncbigene:64223
# FASTK -> ncbigene:10922
# UTP3 -> ncbigene:57050
# CCND2 -> ncbigene:894
# IFI16 -> ncbigene:3428
# CENPJ -> ncbigene:55835
# MAPK4 -> ncbigene:5596
# NPM1 -> ncbigene:4869
# SNAP25 -> ncbigene:6616
# CCDC59 -> ncbigene:29080
# THADA -> ncbigene:63892
# ALX1 -> ncbigene:8092
# ETV1 -> ncbigene:2115
# RPA2 -> ncbigene:6118
# IFNB1 -> ncbigene:3456
# CD3G -> ncbigene:917
# MYOT -> ncbigene:9499
# S1PR4 -> ncbigene:8698
# PNLIP -> ncbigene:5406
# C10orf68 -> ncbigene:79741
# SPG21 -> ncbigene:51324
# C1orf106 -> ncbigene:55765
# NANS -> ncbigene:54187
# BNC2 -> ncbigene:54796
# FBXO11 -> ncbigene:80204
# CAPN10 -> ncbigene:11132
# FAM82A2 -> ncbigene:55177
# SIGIRR -> ncbigene:59307
# RPA4 -> ncbigene:29935
# PRR5 -> ncbigene:55615
# SEMA3D -> ncbigene:223117
# C1orf63 -> ncbigene:57035
# VIP -> ncbigene:7432
# GDPD3 -> ncbigene:79153
# ERGIC3 -> ncbigene:51614
# CSN2 -> ncbigene:1447
# CCNE1 -> ncbigene:898
# TCAP -> ncbigene:8557
# SSRP1 -> ncbigene:6749
# FXR2 -> ncbigene:9513
# PDCD4 -> ncbigene:27250
# DNAJC15 -> ncbigene:29103
# LOC79999 -> ncbigene:79999
# KLF15 -> ncbigene:28999
# TOM1L1 -> ncbigene:10040
# HSP90AB1 -> ncbigene:3326
# TPP1 -> ncbigene:1200
# C10orf12 -> ncbigene:84458
# CNGB3 -> ncbigene:54714
# PLLP -> ncbigene:51090
# KCNB2 -> ncbigene:9312
# LY6G6C -> ncbigene:80740
# ZNF571 -> ncbigene:51276
# ILKAP -> ncbigene:80895
# KCNJ15 -> ncbigene:3772
# EGFL6 -> ncbigene:25975
# SOX9 -> ncbigene:6662
# C22orf30 -> ncbigene:253143
# PHIP -> ncbigene:55023
# TAF1C -> ncbigene:9013
# AMPH -> ncbigene:273
# ACTG1 -> ncbigene:71
# RFX1 -> ncbigene:5989
# EIF3K -> ncbigene:27335
# ZNF318 -> ncbigene:24149
# HDHD1 -> ncbigene:8226
# PHF1 -> ncbigene:5252
# ZNF493 -> ncbigene:284443
# RSBN1 -> ncbigene:54665
# EN1 -> ncbigene:2019
# HOOK1 -> ncbigene:51361
# OCM2 -> ncbigene:4951
# VAT1 -> ncbigene:10493
# ALCAM -> ncbigene:214
# BCCIP -> ncbigene:56647
# WDR48 -> ncbigene:57599
# COL7A1 -> ncbigene:1294
# TNNI3 -> ncbigene:7137
# RPA3 -> ncbigene:6119
# MYO7A -> ncbigene:4647
# AMELX -> ncbigene:265
# YBX2 -> ncbigene:51087
# C8orf55 -> ncbigene:51337
# STOM -> ncbigene:2040
# PDXDC1 -> ncbigene:23042
# FOXD1 -> ncbigene:2297
# ZNF580 -> ncbigene:51157
# TRPC5 -> ncbigene:7224
# NTRK3 -> ncbigene:4916
# PLA1A -> ncbigene:51365
# ZNF480 -> ncbigene:147657
# P4HB -> ncbigene:5034
# RUNX1T1 -> ncbigene:862
# IL1A -> ncbigene:3552
# RCL1 -> ncbigene:10171
# TSPYL4 -> ncbigene:23270
# DGCR8 -> ncbigene:54487
# COL4A1 -> ncbigene:1282
# ZCCHC8 -> ncbigene:55596
# F7 -> ncbigene:2155
# SCD5 -> ncbigene:79966
# MMP13 -> ncbigene:4322
# HSPB11 -> ncbigene:51668
# NOC4L -> ncbigene:79050
# RLF -> ncbigene:6018
# RPS28 -> ncbigene:6234
# HNRNPUL1 -> ncbigene:11100
# PURA -> ncbigene:5813
# TBC1D13 -> ncbigene:54662
# KRT81 -> ncbigene:3887
# PLEKHB2 -> ncbigene:55041
# CLEC5A -> ncbigene:23601
# RPS19 -> ncbigene:6223
# TMEM134 -> ncbigene:80194
# TBC1D8 -> ncbigene:11138
# UQCRH -> ncbigene:7388
# TOMM40 -> ncbigene:10452
# CYLC1 -> ncbigene:1538
# CCNH -> ncbigene:902
# LMX1B -> ncbigene:4010
# IKZF5 -> ncbigene:64376
# CCNB1 -> ncbigene:891
# TMCO6 -> ncbigene:55374
# KCTD14 -> ncbigene:65987
# C1GALT1 -> ncbigene:56913
# MYH4 -> ncbigene:4622
# IRAK3 -> ncbigene:11213
# NNT -> ncbigene:23530
# ACAN -> ncbigene:176
# SCN3B -> ncbigene:55800
# CYP2U1 -> ncbigene:113612
# RGS12 -> ncbigene:6002
# ANKRD17 -> ncbigene:26057
# FNBP1 -> ncbigene:23048
# GNG12 -> ncbigene:55970
# CD2AP -> ncbigene:23607
# NKX3-1 -> ncbigene:4824
# ZNF544 -> ncbigene:27300
# SAMD4B -> ncbigene:55095
# MEP1A -> ncbigene:4224
# MED7 -> ncbigene:9443
# MAP3K13 -> ncbigene:9175
# ETV6 -> ncbigene:2120
# POMC -> ncbigene:5443
# IKBKG -> ncbigene:8517
# GGA3 -> ncbigene:23163
# RPP14 -> ncbigene:11102
# CD160 -> ncbigene:11126
# CDK4 -> ncbigene:1019
# FECH -> ncbigene:2235
# OSBPL9 -> ncbigene:114883
# UXT -> ncbigene:8409
# SLC36A1 -> ncbigene:206358
# CYP4B1 -> ncbigene:1580
# ANKRD46 -> ncbigene:157567
# YIPF6 -> ncbigene:286451
# LOC202181 -> ncbigene:202181
# ACSM5 -> ncbigene:54988
# RHO -> ncbigene:6010
# SLC2A1 -> ncbigene:6513
# ACD -> ncbigene:65057
# MIER2 -> ncbigene:54531
# ARHGEF1 -> ncbigene:9138
# GRK6 -> ncbigene:2870
# PRKAB2 -> ncbigene:5565
# BNIP1 -> ncbigene:662
# TRIM2 -> ncbigene:23321
# KRT32 -> ncbigene:3882
# C1orf115 -> ncbigene:79762
# TRDN -> ncbigene:10345
# TREX2 -> ncbigene:11219
# MOXD1 -> ncbigene:26002
# CHCHD2 -> ncbigene:51142
# TULP2 -> ncbigene:7288
# PLS1 -> ncbigene:5357
# AP3D1 -> ncbigene:8943
# NFATC4 -> ncbigene:4776
# GFI1 -> ncbigene:2672
# UBE4A -> ncbigene:9354
# MSL3 -> ncbigene:10943
# COL1A1 -> ncbigene:1277
# PRKACB -> ncbigene:5567
# GDF9 -> ncbigene:2661
# MDH1 -> ncbigene:4190
# CFD -> ncbigene:1675
# HNRNPH1 -> ncbigene:3187
# ARHGEF40 -> ncbigene:55701
# ITGB1 -> ncbigene:3688
# PDGFA -> ncbigene:5154
# PCSK5 -> ncbigene:5125
# MUM1 -> ncbigene:84939
# SESN1 -> ncbigene:27244
# SNX4 -> ncbigene:8723
# KANK1 -> ncbigene:23189
# CCL13 -> ncbigene:6357
# EIF4EBP1 -> ncbigene:1978
# CDK14 -> ncbigene:5218
# MRPS18B -> ncbigene:28973
# OTUD3 -> ncbigene:23252
# NDRG4 -> ncbigene:65009
# LASS6 -> ncbigene:253782
# SSR1 -> ncbigene:6745
# PGAM1 -> ncbigene:5223
# PNPLA6 -> ncbigene:10908
# ATG10 -> ncbigene:83734
# TBL3 -> ncbigene:10607
# RABEP1 -> ncbigene:9135
# C2CD3 -> ncbigene:26005
# DPYSL3 -> ncbigene:1809
# GRIK4 -> ncbigene:2900
# BAK1 -> ncbigene:578
# BARD1 -> ncbigene:580
# MGA -> ncbigene:23269
# RALGAPB -> ncbigene:57148
# ULK2 -> ncbigene:9706
# FAM5C -> ncbigene:339479
# GUCY2C -> ncbigene:2984
# ARIH2 -> ncbigene:10425
# VKORC1 -> ncbigene:79001
# DPP3 -> ncbigene:10072
# MYH6 -> ncbigene:4624
# IGFBP4 -> ncbigene:3487
# HIST1H2BC -> ncbigene:8347
# ITGBL1 -> ncbigene:9358
# HAAO -> ncbigene:23498
# LPHN1 -> ncbigene:22859
# LIMD1 -> ncbigene:8994
# ZNF75D -> ncbigene:7626
# C16orf58 -> ncbigene:64755
# GPS2 -> ncbigene:2874
# NSFL1C -> ncbigene:55968
# GBP1 -> ncbigene:2633
# DHRS3 -> ncbigene:9249
# RABGAP1L -> ncbigene:9910
# SRSF5 -> ncbigene:6430
# GPRC5A -> ncbigene:9052
# PLA2G1B -> ncbigene:5319
# RNF208 -> ncbigene:727800
# ZNF268 -> ncbigene:10795
# COMMD9 -> ncbigene:29099
# HOXD13 -> ncbigene:3239
# DAPK1 -> ncbigene:1612
# TSPAN2 -> ncbigene:10100
# ATP5H -> ncbigene:10476
# CPSF3L -> ncbigene:54973
# TSKS -> ncbigene:60385
# RNF130 -> ncbigene:55819
# TAPT1 -> ncbigene:202018
# COCH -> ncbigene:1690
# HNF1A -> ncbigene:6927
# LRRC1 -> ncbigene:55227
# PGPEP1 -> ncbigene:54858
# FADS3 -> ncbigene:3995
# CSTA -> ncbigene:1475
# VAV1 -> ncbigene:7409
# EMILIN1 -> ncbigene:11117
# CRYGD -> ncbigene:1421
# PCNXL2 -> ncbigene:80003
# PDK4 -> ncbigene:5166
# UMPS -> ncbigene:7372
# IGFBP7 -> ncbigene:3490
# CALML5 -> ncbigene:51806
# OPRD1 -> ncbigene:4985
# TARBP2 -> ncbigene:6895
# GLI2 -> ncbigene:2736
# WBP11 -> ncbigene:51729
# DUSP26 -> ncbigene:78986
# DONSON -> ncbigene:29980
# PRKCDBP -> ncbigene:112464
# IPO9 -> ncbigene:55705
# SLC27A2 -> ncbigene:11001
# RTCD1 -> ncbigene:8634
# HSPA5 -> ncbigene:3309
# TM9SF1 -> ncbigene:10548
# CDKAL1 -> ncbigene:54901
# GLP2R -> ncbigene:9340
# APCS -> ncbigene:325
# AP3M2 -> ncbigene:10947
# HDC -> ncbigene:3067
# NIT1 -> ncbigene:4817
# OLIG2 -> ncbigene:10215
# WDR19 -> ncbigene:57728
# HLTF -> ncbigene:6596
# GLCE -> ncbigene:26035
# METTL2B -> ncbigene:55798
# FASLG -> ncbigene:356
# EWSR1 -> ncbigene:2130
# CD34 -> ncbigene:947
# IBTK -> ncbigene:25998
# TNIK -> ncbigene:23043
# TLR6 -> ncbigene:10333
# PSMA2 -> ncbigene:5683
# CCNA1 -> ncbigene:8900
# SOX21 -> ncbigene:11166
# MPI -> ncbigene:4351
# EPCAM -> ncbigene:4072
# SI -> ncbigene:6476
# LRRC3 -> ncbigene:81543
# PLP1 -> ncbigene:5354
# SLC11A2 -> ncbigene:4891
# TMEM33 -> ncbigene:55161
# GSG1 -> ncbigene:83445
# PKD1P1 -> ncbigene:339044
# HSPE1 -> ncbigene:3336
# HIGD1A -> ncbigene:25994
# NEO1 -> ncbigene:4756
# HK1 -> ncbigene:3098
# MAP2 -> ncbigene:4133
# OCA2 -> ncbigene:4948
# VDAC2 -> ncbigene:7417
# RAI14 -> ncbigene:26064
# ZZZ3 -> ncbigene:26009
# RRAGD -> ncbigene:58528
# MBD2 -> ncbigene:8932
# IGSF6 -> ncbigene:10261
# KRT19 -> ncbigene:3880
# PEX10 -> ncbigene:5192
# GLB1 -> ncbigene:2720
# ATP5L -> ncbigene:10632
# RCC1 -> ncbigene:1104
# PER1 -> ncbigene:5187
# NFATC1 -> ncbigene:4772
# NRG1 -> ncbigene:3084
# KBTBD11 -> ncbigene:9920
# OPRL1 -> ncbigene:4987
# GAB2 -> ncbigene:9846
# TARS2 -> ncbigene:80222
# RIMBP2 -> ncbigene:23504
# SRRM2 -> ncbigene:23524
# EIF2C4 -> ncbigene:192670
# C5orf4 -> ncbigene:10826
# CSH1 -> ncbigene:1442
# SCYL2 -> ncbigene:55681
# RHBDF1 -> ncbigene:64285
# ROPN1B -> ncbigene:152015
# DMBT1 -> ncbigene:1755
# PCSK6 -> ncbigene:5046
# CSRP2 -> ncbigene:1466
# GIN1 -> ncbigene:54826
# TKT -> ncbigene:7086
# CHAF1A -> ncbigene:10036
# TBX1 -> ncbigene:6899
# ERO1L -> ncbigene:30001
# DMC1 -> ncbigene:11144
# IKBKB -> ncbigene:3551
# VSNL1 -> ncbigene:7447
# SEMA7A -> ncbigene:8482
# KCNJ1 -> ncbigene:3758
# ZNF85 -> ncbigene:7639
# MFN2 -> ncbigene:9927
# MCM2 -> ncbigene:4171
# MBOAT7 -> ncbigene:79143
# AES -> ncbigene:166
# KLHL7 -> ncbigene:55975
# CDKN1C -> ncbigene:1028
# SLC11A1 -> ncbigene:6556
# CNTNAP2 -> ncbigene:26047
# PYCRL -> ncbigene:65263
# SMCR7L -> ncbigene:54471
# FAM164A -> ncbigene:51101
# FRAT1 -> ncbigene:10023
# GATAD2A -> ncbigene:54815
# AP4E1 -> ncbigene:23431
# ACP1 -> ncbigene:52
# ZC3H15 -> ncbigene:55854
# TNFSF11 -> ncbigene:8600
# CLDN18 -> ncbigene:51208
# MAPK13 -> ncbigene:5603
# IVD -> ncbigene:3712
# KLK3 -> ncbigene:354
# HOXB2 -> ncbigene:3212
# ZIC3 -> ncbigene:7547
# SLC25A40 -> ncbigene:55972
# NR6A1 -> ncbigene:2649
# KCNJ9 -> ncbigene:3765
# CCT5 -> ncbigene:22948
# REPS1 -> ncbigene:85021
# COL5A3 -> ncbigene:50509
# MPL -> ncbigene:4352
# MBNL1 -> ncbigene:4154
# ABCD3 -> ncbigene:5825
# ZNF552 -> ncbigene:79818
# ADAP2 -> ncbigene:55803
# HOXD1 -> ncbigene:3231
# TFAP2B -> ncbigene:7021
# PWP1 -> ncbigene:11137
# CCL4 -> ncbigene:6351
# NDUFB6 -> ncbigene:4712
# FBXO9 -> ncbigene:26268
# ACTN4 -> ncbigene:81
#          Gene1      Gene2 pdi ppi          Rep1            Rep2
# 0          AHR     CYP1A1   1   0  ncbigene:196            None
# 1       PHOX2A        DBH   1   0          None            None
# 2         ATF1        GSN   1   0          None            None
# 3         ATF1      TEAD1   1   0          None            None
# 4        PRDM1      CIITA   1   0          None            None
# 5        RUNX2      MMP13   1   0          None   ncbigene:4322
# 6        RUNX2  TNFRSF11B   1   0          None            None
# 7        RUNX1      CSF1R   1   0          None            None
# 8         CDX2     GUCY2C   1   0          None   ncbigene:2984
# 9         CDX2         SI   1   0          None   ncbigene:6476
# 10       CEBPA      PPARG   1   0          None            None
# 11       CEBPB        IL6   1   0          None            None
# 12       CEBPB        IL8   1   0          None            None
# 13       CEBPB  TNFRSF10B   1   0          None            None
# 14       CREB1       BDNF   1   0          None            None
# 15       CREB1       CFTR   1   0          None            None
# 16       CREB1        FOS   1   0          None            None
# 17       CREB1       IBSP   1   0          None            None
# 18       CREB1       MITF   1   0          None            None
# 19       CREB1      PSEN1   1   0          None            None
# 20       CREB1        TRH   1   0          None            None
# 21        ATF2        FOS   1   0          None            None
# 22        ATF2        RB1   1   0          None            None
# 23        CREM      CCNA2   1   0          None            None
# 24      NKX2-5       NPPA   1   0          None            None
# 25        CUX1       CYBB   1   0          None            None
# 26        E2F1      CCND1   1   0          None            None
# 27        E2F1      CCNA2   1   0          None            None
# 28        E2F1      CCNE1   1   0          None    ncbigene:898
# 29        E2F1       CDK1   1   0          None            None
# ...        ...        ...  ..  ..           ...             ...
# 38397    RAP1B      RAP2B   0   1          None            None
# 38398  RAP1GAP       RHEB   0   1          None            None
# 38399    RAP2A       RGL1   0   1          None  ncbigene:23179
# 38400    RAP2B       RGL1   0   1          None  ncbigene:23179
# 38401    RASA1    CNTNAP1   0   1          None            None
# 38402    RASA1    SYNCRIP   0   1          None            None
# 38403    RASA1      MMRN1   0   1          None            None
# 38404    RASA1       SND1   0   1          None            None
# 38405  RASGRF1       RRAD   0   1          None            None
# 38406  RASGRF1      PDZD2   0   1          None            None
# 38407      RB1       RBL1   0   1          None            None
# 38408      RB1    SMARCA2   0   1          None            None
# 38409      RB1   TNFRSF1A   0   1          None   ncbigene:7132
# 38410      RB1       TP53   0   1          None            None
# 38411      RB1    TP53BP1   0   1          None            None
# 38412      RB1        YY1   0   1          None            None
# 38413      RB1      HDAC9   0   1          None            None
# 38414      RB1      IKZF1   0   1          None            None
# 38415      RB1       IRF9   0   1          None            None
# 38416      RB1       CTCF   0   1          None            None
# 38417      RB1   PPP1R13B   0   1          None            None
# 38418      RB1       CBX5   0   1          None            None
# 38419      RB1     ATP8A2   0   1          None            None
# 38420    RBBP4      HDAC6   0   1          None            None
# 38421    RBBP4      HDAC5   0   1          None            None
# 38422    RBBP4     CHAF1A   0   1          None  ncbigene:10036
# 38423    RBBP4    TBL1XR1   0   1          None            None
# 38424    RBBP4      TBL1Y   0   1          None            None
# 38425    RBBP7        WT1   0   1          None            None
# 38426        R                             None            None
#
# [38427 rows x 6 columns]
# finished...

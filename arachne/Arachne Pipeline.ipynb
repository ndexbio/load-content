# %% [markdown]
# # Arachne Pipeline

# %% [markdown]
# This notebook creates a network using Arachne-generated data.

# %% [markdown]
# ## Imports Python Packages Needed in the Pipeline

# %%
import ndex2.client as nc
import json
import pandas as pd
import sys
import jsonschema
import requests
import ndexutil.tsv.tsv2nicecx as t2n
from os.path import isfile, expanduser
from os import listdir

# %% [markdown]
# ### NDEx Connection Function

# %%
def load_tutorial_config(connection_name):
    username = "foo"
    password = None
    config_file = expanduser("~/ndex_tutorial_config.json")
    server = "http://public.ndexbio.org"

    if isfile(config_file):
        file = open(config_file, "r")
        config = json.load(file)
        file.close()
        print(json.dumps(config))
        connections = config.get("connections")
        if connections:
            if connection_name:
                connection = connections.get(connection_name)
                if connection.get("password") and connection.get("username"):
                    if connection.get("server"):
                        server = connection.get("server")
                    username = connection.get("username")
                    password = connection.get("password")
                else:
                    print("Error: " + str(connection_name) + " does not define both username and password")
            else:
                print("Error: " + str(connection_name) + "connection name is not defined")
        else:
            print("Error: " + config_file + " does not define any connections")
    else:
        print("Error: " + config_file + " was not found")

    return server, username, password

# %% [markdown]
# ### MyGene.info Access Functions

# %%
def query(q, tax_id='9606', entrezonly=True):
    if entrezonly:
        r = requests.get('http://mygene.info/v3/query?q='+q+'&species='+tax_id+'&entrezonly=true')
    else:
        r = requests.get('http://mygene.info/v3/query?q='+q+'&species='+tax_id)
    result = r.json()
    result['query'] = q
    return result

# run multiple queries and gather results
def query_list(queries, tax_id='9606', fields='sym'):
    results = []
    for q in queries:
        results.append(query(q, tax_id))
    return results

# use the mygene.info efficient batch query method
# to process multiple identifers in one operation
def query_batch(
        query_string,
        tax_id='9606',
        scopes="symbol, entrezgene, alias, uniprot",
        fields="symbol, entrezgene"):
    data = {'species': tax_id,
            'scopes': scopes,
            'fields': fields,
            'q': query_string}
    r = requests.post('http://mygene.info/v3/query', data)
    json = r.json()
    return json

def split_to_lists(input_list, target_length=5000):
    '''splits list of strings into sublists, each 
    having string length at most 5000'''
    out = [[]]
    while input_list:
        if len("', '".join(out[-1])) + len(input_list[0]) < target_length:
            out[-1].append(input_list.pop(0))
        else:
            if not out[-1]: # string longer than target_length
                out[-1] = [input_list.pop(0)]
            out.append([])
    return out

def query_large_batch(
        input_ids,
        scopes=["symbol", "entrezgene", "uniprot"],
        field ="entrezgene",
        tax_id='9606',
        prefix = "ncbigene"):
    all_query_results = []
    input_id_lists = split_to_lists(input_ids)
    for id_list in input_id_lists:
        query_string = ", ".join(id_list)
        scope_string = ", ".join(scopes)
        query_results = query_batch(
            query_string,
            scopes=scope_string,
            fields=field,
            tax_id=tax_id)
        print("query batch: ids: " + str(len(id_list)) + " -> results: " + str(len(query_results)))
        all_query_results.extend(query_results)
    return all_query_results

# --------------------------------------------------
#
#  translation methods
#
# --------------------------------------------------

# return:
# 1. a dictionary mapping identifiers in input_ids
# to identifiers types in scopes. When there are ambiguous
# mappings, the highest ranked mapping is chosen and the
# others are placed in an "alternatives" attribute.
# 2. a list of unmapped input_ids
#
# The mygene.info search is limited to the identifier types in scopes.
#
# The results are limited to the species specified by tax_id.

# Optionally, prefix_map may be set to a dictionary mapping
# identifier types to prefixes to prepend to mapped ids, e.g. <prefix>:<id>
#
def get_identifier_map(
        input_ids,
        scopes=["symbol", "entrezgene", "uniprot"],
        field ="entrezgene",
        tax_id='9606',
        prefix = "ncbigene"):
    query_results = query_large_batch(
        input_ids,
        scopes=scopes,
        field =field,
        tax_id=tax_id,
        prefix = prefix)
    map = {}
    for result in query_results:
        # print(json.dumps(result))
        output_id = result.get(field)
        input_id = result.get("query")
        if output_id:
            mapping = map.get(input_id)
            if mapping:
                # if there is already a mapping, 
                # we test to see the new mapping
                # has a better score
                if mapping.get("_score") < result.get("_score"):
                    map[input_id] = result
            else:
                map[input_id] = result

    # make output map, add prefixes
    output_map = {}
    for input_id, mapping in map.items():
        output_map[input_id] = prefix + ":" + str(mapping.get(field))
    
    # scan query results and populate unmmaped
    unmapped = []
    for result in query_results:
        input_id = result.get("query")
        if not output_map.get(input_id):
            unmapped.append(input_id)
    unmapped = list(set(unmapped))    
    return output_map, unmapped

# %% [markdown]
# ### Set variables
# Note: The load_tutorial_config() function uses a file in the user's home directory (**~/ndex_tutorial_config.json**).  A sample json file is included in the root of this project (also named "ndex_tutorial_config.json").  Edit this file and copy it to your user home directory.  Alternatively you can just use the hardcoded variables below.

# %%
my_server, my_username, my_password = load_tutorial_config("main")
# alternatively, edit and uncomment these lines to set the connection parameters manually
#my_server = "public.ndexbio.org"
#my_username = 'username'
#my_password = 'password'

if 'dev.ndexbio.org' in my_server:
    cytoscape_visual_properties_template_id = 'c7075eb1-231e-11e8-894b-525400c25d22' # DEV
else:
    cytoscape_visual_properties_template_id = '06afeea7-2e04-11e8-b939-0ac135e8bacf' # PUBLIC

my_ndex=nc.Ndex2(my_server, my_username, my_password)
print(my_server)
print(my_username)
print(my_password)
# Out:
# {"connections": {"main": {"username": "drh", "password": "drh"}}}
# http://public.ndexbio.org
# drh
# drh

# %% [markdown]
# ### Set load plan
# Note: To see the field mapping (load plan) open **arachne_load_plan.json**. This json file resides in the same directory as this notebook

# %%
path_to_load_plan = 'load_plan.json'
load_plan = None
with open(path_to_load_plan, 'r') as lp:
    load_plan = json.load(lp)

# %% [markdown]
# ### Process Arachne networks

# %%
def process_arachne_networks(load_plan):
    print('starting...')
    for file in listdir("data"):
        if file.endswith(".txt"):   
            print("processing " + file)
            process_arachne_network(load_plan, "data/" + file)
    print('finished...')
        
def process_arachne_network(load_plan, file):
    # @CONTEXT is set from the load plan
    with open(file, 'r') as tsvfile:
        header = [h.strip() for h in tsvfile.readline().split('\t')]
        df = pd.read_csv(
            tsvfile, 
            delimiter='\t', 
            na_filter=False, 
            engine='python', names=header)
    
    # ncbigene symbols are prefixed
    # create translation map for gene symbols
    node_identifiers = list(set(df["Gene1"].tolist() + df["Gene2"].tolist()))
    print(str(len(node_identifiers)) + " node_identifiers")
    identifier_map, unmapped_identifiers = get_identifier_map(
        node_identifiers,
        scopes = ["symbol", "alias"],
        field = "entrezgene",
        tax_id='9606',
        prefix = "ncbigene")    
    print(json.dumps(unmapped_identifiers))
    print(str(len(identifier_map.keys())) + " map entries")
    
    # for input_id, output_id in identifier_map.items():
    #    print(input_id + " -> " + output_id)
    
    # add columns Rep1 and Rep2 and translate Gene1 and Gene2
    df['Rep1'] = df['Gene1'].apply(lambda x: identifier_map.get(x)) # if identifier_map.get(x) else x)
    df['Rep2'] = df['Gene2'].apply(lambda x: identifier_map.get(x)) # if identifier_map.get(x) else x)
    
    print(df)

    # if the represents field is empty, substitute the gene name
#    df['Rep1'].replace('', df['Gene1'], inplace=True)
#    df['Rep2'].replace('', df['Gene2'], inplace=True)

#def convert_pandas_to_nice_cx_with_load_plan(pandas_dataframe, load_plan, max_rows=None,
#                                            name=None, description=None,
#                                            network_attributes=None, provenance=None):
    network = t2n.convert_pandas_to_nice_cx_with_load_plan(df, load_plan)

#    network.set_network_attribute("organism", "Human, 9606, Homo sapiens")
#    network.union_node_attributes('alias', 'alias2', 'alias')

    network.apply_template(username=my_username, password=my_password, server=my_server,
                           uuid=cytoscape_visual_properties_template_id)
    message = network.upload_to(my_server, my_username, my_password)

# %%
process_arachne_networks(load_plan)
# Out:
# starting...
# processing BreastCancerMCF7-CMAP.txt
# 9571 node_identifiers
# query batch: ids: 54 -> results: 60
# query batch: ids: 54 -> results: 61
# query batch: ids: 55 -> results: 64
# query batch: ids: 54 -> results: 61
# query batch: ids: 57 -> results: 62
# query batch: ids: 53 -> results: 63
# query batch: ids: 53 -> results: 60
# query batch: ids: 54 -> results: 63
# query batch: ids: 53 -> results: 60
# query batch: ids: 55 -> results: 61
# query batch: ids: 56 -> results: 59
# query batch: ids: 55 -> results: 65
# query batch: ids: 55 -> results: 59
# query batch: ids: 55 -> results: 57
# query batch: ids: 54 -> results: 59
# query batch: ids: 54 -> results: 55
# query batch: ids: 57 -> results: 77
# query batch: ids: 55 -> results: 62
# query batch: ids: 54 -> results: 60
# query batch: ids: 55 -> results: 58
# query batch: ids: 54 -> results: 63
# query batch: ids: 55 -> results: 66
# query batch: ids: 55 -> results: 63
# query batch: ids: 54 -> results: 65
# query batch: ids: 55 -> results: 70
# query batch: ids: 54 -> results: 60
# query batch: ids: 54 -> results: 57
# query batch: ids: 55 -> results: 59
# query batch: ids: 56 -> results: 66
# query batch: ids: 54 -> results: 58
# query batch: ids: 55 -> results: 65
# query batch: ids: 55 -> results: 63
# query batch: ids: 54 -> results: 57
# query batch: ids: 54 -> results: 65
# query batch: ids: 53 -> results: 56
# query batch: ids: 54 -> results: 61
# query batch: ids: 53 -> results: 61
# query batch: ids: 52 -> results: 56
# query batch: ids: 56 -> results: 65
# query batch: ids: 55 -> results: 65
# query batch: ids: 55 -> results: 62
# query batch: ids: 54 -> results: 59
# query batch: ids: 55 -> results: 58
# query batch: ids: 54 -> results: 56
# query batch: ids: 54 -> results: 58
# query batch: ids: 55 -> results: 67
# query batch: ids: 55 -> results: 56
# query batch: ids: 53 -> results: 61
# query batch: ids: 54 -> results: 64
# query batch: ids: 53 -> results: 59
# query batch: ids: 54 -> results: 64
# query batch: ids: 53 -> results: 56
# query batch: ids: 55 -> results: 72
# query batch: ids: 55 -> results: 62
# query batch: ids: 54 -> results: 58
# query batch: ids: 54 -> results: 57
# query batch: ids: 52 -> results: 54
# query batch: ids: 54 -> results: 66
# query batch: ids: 54 -> results: 60
# query batch: ids: 54 -> results: 57
# query batch: ids: 54 -> results: 64
# query batch: ids: 55 -> results: 69
# query batch: ids: 54 -> results: 59
# query batch: ids: 55 -> results: 70
# query batch: ids: 55 -> results: 58
# query batch: ids: 56 -> results: 64
# query batch: ids: 55 -> results: 71
# query batch: ids: 55 -> results: 65
# query batch: ids: 54 -> results: 63
# query batch: ids: 54 -> results: 64
# query batch: ids: 53 -> results: 63
# query batch: ids: 55 -> results: 65
# query batch: ids: 56 -> results: 61
# query batch: ids: 55 -> results: 59
# query batch: ids: 57 -> results: 80
# query batch: ids: 53 -> results: 54
# query batch: ids: 54 -> results: 61
# query batch: ids: 54 -> results: 57
# query batch: ids: 54 -> results: 60
# query batch: ids: 55 -> results: 60
# query batch: ids: 55 -> results: 65
# query batch: ids: 54 -> results: 64
# query batch: ids: 55 -> results: 62
# query batch: ids: 56 -> results: 61
# query batch: ids: 55 -> results: 59
# query batch: ids: 56 -> results: 81
# query batch: ids: 55 -> results: 67
# query batch: ids: 54 -> results: 60
# query batch: ids: 54 -> results: 61
# query batch: ids: 57 -> results: 70
# query batch: ids: 53 -> results: 61
# query batch: ids: 55 -> results: 64
# query batch: ids: 55 -> results: 66
# query batch: ids: 56 -> results: 68
# query batch: ids: 54 -> results: 65
# query batch: ids: 55 -> results: 60
# query batch: ids: 54 -> results: 65
# query batch: ids: 54 -> results: 63
# query batch: ids: 55 -> results: 60
# query batch: ids: 56 -> results: 67
# query batch: ids: 55 -> results: 64
# query batch: ids: 55 -> results: 65
# query batch: ids: 53 -> results: 68
# query batch: ids: 53 -> results: 61
# query batch: ids: 55 -> results: 57
# query batch: ids: 54 -> results: 59
# query batch: ids: 54 -> results: 62
# query batch: ids: 55 -> results: 59
# query batch: ids: 55 -> results: 58
# query batch: ids: 55 -> results: 69
# query batch: ids: 53 -> results: 56
# query batch: ids: 55 -> results: 62
# query batch: ids: 54 -> results: 64
# query batch: ids: 55 -> results: 57
# query batch: ids: 55 -> results: 62
# query batch: ids: 55 -> results: 59
# query batch: ids: 53 -> results: 56
# query batch: ids: 54 -> results: 62
# query batch: ids: 54 -> results: 62
# query batch: ids: 55 -> results: 76
# query batch: ids: 55 -> results: 63
# query batch: ids: 56 -> results: 64
# query batch: ids: 53 -> results: 60
# query batch: ids: 55 -> results: 61
# query batch: ids: 56 -> results: 69
# query batch: ids: 53 -> results: 58
# query batch: ids: 54 -> results: 73
# query batch: ids: 55 -> results: 61
# query batch: ids: 56 -> results: 61
# query batch: ids: 53 -> results: 55
# query batch: ids: 53 -> results: 63
# query batch: ids: 55 -> results: 69
# query batch: ids: 55 -> results: 65
# query batch: ids: 54 -> results: 60
# query batch: ids: 55 -> results: 64
# query batch: ids: 54 -> results: 57
# query batch: ids: 57 -> results: 70
# query batch: ids: 53 -> results: 57
# query batch: ids: 54 -> results: 58
# query batch: ids: 55 -> results: 64
# query batch: ids: 56 -> results: 69
# query batch: ids: 54 -> results: 54
# query batch: ids: 54 -> results: 59
# query batch: ids: 55 -> results: 65
# query batch: ids: 54 -> results: 63
# query batch: ids: 54 -> results: 58
# query batch: ids: 54 -> results: 60
# query batch: ids: 53 -> results: 67
# query batch: ids: 55 -> results: 62
# query batch: ids: 56 -> results: 64
# query batch: ids: 54 -> results: 91
# query batch: ids: 54 -> results: 64
# query batch: ids: 55 -> results: 65
# query batch: ids: 53 -> results: 61
# query batch: ids: 53 -> results: 60
# query batch: ids: 53 -> results: 58
# query batch: ids: 53 -> results: 60
# query batch: ids: 54 -> results: 62
# query batch: ids: 54 -> results: 57
# query batch: ids: 55 -> results: 63
# query batch: ids: 54 -> results: 64
# query batch: ids: 53 -> results: 61
# query batch: ids: 53 -> results: 56
# query batch: ids: 54 -> results: 60
# query batch: ids: 56 -> results: 64
# query batch: ids: 55 -> results: 58
# query batch: ids: 54 -> results: 67
# query batch: ids: 55 -> results: 60
# query batch: ids: 54 -> results: 62
# query batch: ids: 53 -> results: 58
# query batch: ids: 53 -> results: 55
# query batch: ids: 54 -> results: 64
# query batch: ids: 55 -> results: 59
# query batch: ids: 55 -> results: 64
# query batch: ids: 54 -> results: 57
# query batch: ids: 47 -> results: 50
# ["MGC29506", "KIAA0174", "6-Mar", "KIAA1045", "LOC26102", "MGC5590", "2-Sep", "15-Sep", "11-Sep", "C8orf60", "8-Mar", "FLJ21369", "LOC100129648", "LOC100127886", "LOC100272216", "7-Sep", "KIAA0894", "8-Sep", "9-Sep", "LOC100288413", "2-Mar", "LOC57399", "LOC100272228", "FLJ11292", "6-Sep", "LOC729164", "LOC55908", "10-Sep"]
# 9542 map entries
#          Gene1      Gene2 pdi ppi           Rep1            Rep2
# 0          AHR     CYP1A1   1   0   ncbigene:196   ncbigene:1543
# 1       PHOX2A        DBH   1   0   ncbigene:401   ncbigene:1621
# 2         ATF1        GSN   1   0   ncbigene:466   ncbigene:2934
# 3         ATF1      TEAD1   1   0   ncbigene:466   ncbigene:7003
# 4        PRDM1      CIITA   1   0   ncbigene:639   ncbigene:4261
# 5        RUNX2      MMP13   1   0   ncbigene:860   ncbigene:4322
# 6        RUNX2  TNFRSF11B   1   0   ncbigene:860   ncbigene:4982
# 7        RUNX1      CSF1R   1   0   ncbigene:861   ncbigene:1436
# 8         CDX2     GUCY2C   1   0  ncbigene:1045   ncbigene:2984
# 9         CDX2         SI   1   0  ncbigene:1045   ncbigene:6476
# 10       CEBPA      PPARG   1   0  ncbigene:1050   ncbigene:5468
# 11       CEBPB        IL6   1   0  ncbigene:1051   ncbigene:3569
# 12       CEBPB        IL8   1   0  ncbigene:1051   ncbigene:3576
# 13       CEBPB  TNFRSF10B   1   0  ncbigene:1051   ncbigene:8795
# 14       CREB1       BDNF   1   0  ncbigene:1385    ncbigene:627
# 15       CREB1       CFTR   1   0  ncbigene:1385   ncbigene:1080
# 16       CREB1        FOS   1   0  ncbigene:1385   ncbigene:2353
# 17       CREB1       IBSP   1   0  ncbigene:1385   ncbigene:3381
# 18       CREB1       MITF   1   0  ncbigene:1385   ncbigene:4286
# 19       CREB1      PSEN1   1   0  ncbigene:1385   ncbigene:5663
# 20       CREB1        TRH   1   0  ncbigene:1385   ncbigene:7200
# 21        ATF2        FOS   1   0  ncbigene:1386   ncbigene:2353
# 22        ATF2        RB1   1   0  ncbigene:1386   ncbigene:5925
# 23        CREM      CCNA2   1   0  ncbigene:1390    ncbigene:890
# 24      NKX2-5       NPPA   1   0  ncbigene:1482   ncbigene:4878
# 25        CUX1       CYBB   1   0  ncbigene:1523   ncbigene:1536
# 26        E2F1      CCND1   1   0  ncbigene:1869    ncbigene:595
# 27        E2F1      CCNA2   1   0  ncbigene:1869    ncbigene:890
# 28        E2F1      CCNE1   1   0  ncbigene:1869    ncbigene:898
# 29        E2F1       CDK1   1   0  ncbigene:1869    ncbigene:983
# ...        ...        ...  ..  ..            ...             ...
# 38397    RAP1B      RAP2B   0   1  ncbigene:5908   ncbigene:5912
# 38398  RAP1GAP       RHEB   0   1  ncbigene:5909   ncbigene:6009
# 38399    RAP2A       RGL1   0   1  ncbigene:5911  ncbigene:23179
# 38400    RAP2B       RGL1   0   1  ncbigene:5912  ncbigene:23179
# 38401    RASA1    CNTNAP1   0   1  ncbigene:5921   ncbigene:8506
# 38402    RASA1    SYNCRIP   0   1  ncbigene:5921  ncbigene:10492
# 38403    RASA1      MMRN1   0   1  ncbigene:5921  ncbigene:22915
# 38404    RASA1       SND1   0   1  ncbigene:5921  ncbigene:27044
# 38405  RASGRF1       RRAD   0   1  ncbigene:5923   ncbigene:6236
# 38406  RASGRF1      PDZD2   0   1  ncbigene:5923  ncbigene:23037
# 38407      RB1       RBL1   0   1  ncbigene:5925   ncbigene:5933
# 38408      RB1    SMARCA2   0   1  ncbigene:5925   ncbigene:6595
# 38409      RB1   TNFRSF1A   0   1  ncbigene:5925   ncbigene:7132
# 38410      RB1       TP53   0   1  ncbigene:5925   ncbigene:7157
# 38411      RB1    TP53BP1   0   1  ncbigene:5925   ncbigene:7158
# 38412      RB1        YY1   0   1  ncbigene:5925   ncbigene:7528
# 38413      RB1      HDAC9   0   1  ncbigene:5925   ncbigene:9734
# 38414      RB1      IKZF1   0   1  ncbigene:5925  ncbigene:10320
# 38415      RB1       IRF9   0   1  ncbigene:5925  ncbigene:10379
# 38416      RB1       CTCF   0   1  ncbigene:5925  ncbigene:10664
# 38417      RB1   PPP1R13B   0   1  ncbigene:5925  ncbigene:23368
# 38418      RB1       CBX5   0   1  ncbigene:5925  ncbigene:23468
# 38419      RB1     ATP8A2   0   1  ncbigene:5925  ncbigene:51761
# 38420    RBBP4      HDAC6   0   1  ncbigene:5928  ncbigene:10013
# 38421    RBBP4      HDAC5   0   1  ncbigene:5928  ncbigene:10014
# 38422    RBBP4     CHAF1A   0   1  ncbigene:5928  ncbigene:10036
# 38423    RBBP4    TBL1XR1   0   1  ncbigene:5928  ncbigene:79718
# 38424    RBBP4      TBL1Y   0   1  ncbigene:5928  ncbigene:90665
# 38425    RBBP7        WT1   0   1  ncbigene:5931   ncbigene:7490
# 38426        R                     ncbigene:7143            None
#
# [38427 rows x 6 columns]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-118-926250901130> in <module>()
# ----> 1 process_arachne_networks(load_plan)
#
# <ipython-input-117-485c09c9cf4e> in process_arachne_networks(load_plan)
#       4         if file.endswith(".txt"):
#       5             print("processing " + file)
# ----> 6             process_arachne_network(load_plan, "data/" + file)
#       7     print('finished...')
#       8
#
# <ipython-input-117-485c09c9cf4e> in process_arachne_network(load_plan, file)
#      46 #                                            name=None, description=None,
#      47 #                                            network_attributes=None, provenance=None):
# ---> 48     network = t2n.convert_pandas_to_nice_cx_with_load_plan(df, load_plan)
#      49
#      50 #    network.set_network_attribute("organism", "Human, 9606, Homo sapiens")
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ndexutil/tsv/tsv2nicecx.py in convert_pandas_to_nice_cx_with_load_plan(pandas_dataframe, load_plan, max_rows, name, description, network_attributes, provenance)
#      41     for index, row in pandas_dataframe.iterrows():
#      42         # As each row is processed, self.G_nx is updated
# ---> 43         process_row(nice_cx, load_plan, row, node_lookup)
#      44         row_count = row_count + 1
#      45         if max_rows and row_count > max_rows + 2:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ndexutil/tsv/tsv2nicecx.py in process_row(nice_cx, load_plan, row, node_lookup)
#      97
#      98     source_node = create_node(row, load_plan.get('source_plan'), nice_cx, node_lookup)
# ---> 99     target_node = create_node(row, load_plan.get('target_plan'), nice_cx, node_lookup)
#     100
#     101     create_edge(nice_cx, source_node.get_id(), target_node.get_id(), row, load_plan)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/ndexutil/tsv/tsv2nicecx.py in create_node(row, node_plan, nice_cx, node_lookup)
#     125
#     126     if not ext_id:
# --> 127         raise RuntimeError("Id value is missing.")
#     128
#     129     if node_plan.get('rep_prefix'):
#
# RuntimeError: Id value is missing.

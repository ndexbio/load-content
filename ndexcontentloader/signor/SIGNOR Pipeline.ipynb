# %% [markdown]
# # SIGNOR Pipeline

# %% [markdown]
# This notebook creates a Network Set of SIGNOR pathway networks using the latest data downloaded via the SIGNOR REST service. SIGNOR is updated regularly and so it also demonstrates how to update the networks in the set.

# %% [markdown]
# ## Imports Python Packages Needed in the Pipeline

# %%
#!pip uninstall ndexutil -y
#!pip install ndexutil --no-cache-dir
#!pip uninstall ndex2-dev -y
#!pip uninstall ndex2-dev -y
#!pip install ndex2-dev --no-cache-dir
#!pip freeze

# %%
import ndex2 # The ndex2 Python client
from ndex2.cx.aspects import ATTRIBUTE_DATA_TYPE
import ndex2.client as nc
import itertools # convenient iteration utilities 
import requests
import json
import pandas as pd
import io
import sys
import jsonschema
import os
import nicecxModel
#from nicecxModel.cx.aspects import ATTRIBUTE_DATA_TYPE
from datetime import datetime
#import datetime
import networkx as nx
sys.path.append('../../resources')
from tutorial_utils import load_tutorial_config

# %%
import ndexutil.tsv.tsv2nicecx as t2n

# %%
signor_list_url = 'https://signor.uniroma2.it/getPathwayData.php?list'
#response_list = requests.get(signor_list_url)
#signor_mapping_list = response_list.text
cols = ['pathway_id', 'pathway_name']
species_mapping = {'9606': 'Human', '10090': 'Mouse', '10116': 'Rat'}
species = ['9606', '10090', '10116']
signor_mapping_list_df = pd.read_csv(signor_list_url, sep="\t", names = cols)
#print(signor_mapping_list_df)

# %% [markdown]
# ## NDEx Access
#
# Configure your NDEx connection based on server, account and password.
#
# See ["Using NDEx Tutorial Config Files.ipynb"] for more information.

# %%
# get the connection parameters from the ndex_tutorial_config.json file in your home directory.
# edit the line below to specify a different connection in the config file
#my_server, my_username, my_password = load_tutorial_config("main")

# alternatively, edit and uncomment these lines to set the connection parameters manually 
my_server = "dev.ndexbio.org"
my_username = 'scratch'
my_password = 'scratch'

my_ndex=ndex2.client.Ndex2(my_server, my_username, my_password)

# %%
def get_signor_update_mapping(server, username, password):
    signor_mapping_set = {}
    signor_list_url = 'https://signor.uniroma2.it/getPathwayData.php?list'
    cols = ['pathway_id', 'pathway_name']

    signor_mapping_list_df = pd.read_csv(signor_list_url, sep="\t", names=cols)
    signor_dict = signor_mapping_list_df.to_dict()

    id_to_name = {}
    pathway_names = signor_dict.get('pathway_name')
    pathway_id = signor_dict.get('pathway_id')
    for k, v in pathway_names.items():
        signor_mapping_set[v] = k
        id_to_name[pathway_id.get(k)] = v
        
    my_ndex = nc.Ndex2(server, username, password)
    networks = my_ndex.get_network_summaries_for_user(username)
    update_mapping = {}
    for nk in networks:
        if nk.get('name') is not None:
            if signor_mapping_set.get(nk.get('name')) is not None or 'FULL-' in nk.get('name').upper():
                if 'FULL-HUMAN' in nk.get('name').upper():
                    update_mapping['FULL-Human (' + f"{datetime.now():%d-%b-%Y}" + ')'] = nk.get('externalId')
                elif 'FULL-MOUSE' in nk.get('name').upper():
                    update_mapping['FULL-Mouse (' + f"{datetime.now():%d-%b-%Y}" + ')'] = nk.get('externalId')
                elif 'FULL-RAT' in nk.get('name').upper():
                    update_mapping['FULL-Rat (' + f"{datetime.now():%d-%b-%Y}" + ')'] = nk.get('externalId')
                else:
                    update_mapping[nk.get('name').upper()] = nk.get('externalId')

    return (update_mapping, id_to_name)

update_signor_mapping, signor_id_name_mapping = get_signor_update_mapping(my_server, my_username, my_password)
#print(update_signor_mapping)

# %% [markdown]
# ## Get the Pathway Ids from the Mapping File:

# %%
def get_signor_network_ids():
    #path = "signor-path_mapping_file.txt"
    #return pd.read_csv(path, sep="\t")

    signor_list_url = 'https://signor.uniroma2.it/getPathwayData.php?list'
    #response_list = requests.get(signor_list_url)
    #signor_mapping_list = response_list.text
    cols = ['pathway_id', 'pathway_name']
    return pd.read_csv(signor_list_url, sep="\t", names = cols)

network_id_dataframe = get_signor_network_ids()
# network_id_dataframe

# %% [markdown]
# ## Get the Load Plan:
#
# (TODO: validate load plan with jsonschema)

# %%
try:
    path_to_load_plan = 'signor_load_plan.json'
    load_plan = None
    with open(path_to_load_plan, 'r') as lp:
        load_plan = json.load(lp)
        
except jsonschema.ValidationError as e1:
    print("Failed to parse the loading plan: " + e1.message)
    print('at path: ' + str(e1.absolute_path))
    print("in block: ")
    print(e1.instance)

# %% [markdown]
# ## Function to Create NiceCX from SIGNOR Pathway Data

# %%
# human_tax_id = "9606"

def get_signor_network(pathway_id, load_plan):
    # TODO - add context (normalize?)
    # @CONTEXT is set from the load plan
    
    url = "http://signor.uniroma2.it/getPathwayData.php?pathway=" + pathway_id + "&relations=only"
    # print(url)
    response = requests.get(url)
    pathway_data = response.text
    
    #header = [h.strip() for h in pathway_data.readline().split('\t')]
    #print(pathway_data)
    # converters={'CUSTOMER': str, 'ORDER NO': str}
    #converters = {}
    usecols = ["entitya", "typea", "ida", "entityb", "typeb", "idb", "effect", "mechanism", "residue", "sequence", "tax_id", "cell_data", "tissue_data", "pmid", "direct", "notes", "annotator", "sentence"]
    #usecols = ["ENTITYA", "TYPEA", "IDA", "ENTITYB", "TYPEB", "IDB", "EFFECT", "MECHANISM", "RESIDUR", 
    #           "SEQUENCE", "TAX_ID", "CELL_DATA", "TISSUE_DATA", "PMID", "DIRECT", "NOTES", "ANNOTATOR", "SETENCE"]
    #for col in usecols:
    #    converters[col] = str
    # dataframe = pd.read_csv(io.StringIO(pathway_data), sep='\t',converters = converters,usecols = usecols)
    dataframe = pd.read_csv(io.StringIO(pathway_data), 
                dtype=str, 
                na_filter=False, 
                delimiter='\t', 
                engine='python')
                #names=usecols)
    
    #print(dataframe)
    #print(dataframe)
    # filter dataframe to remove rows that are not human
    human_dataframe = dataframe #.loc[dataframe["tax_id"] == "9606"]

    #print(human_dataframe)
    # upcase column names
    rename = {}
    for column_name in human_dataframe.columns:
        rename[column_name]= column_name.upper()
    
    human_dataframe = human_dataframe.rename(columns=rename)

    # df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})
    #return human_dataframe
    
    network = t2n.convert_pandas_to_nice_cx_with_load_plan(human_dataframe, load_plan)

    #network.set_network_attribute("SIGNOR_ID", values=pathway_id)

    # Fix values for "DIRECT"
    for edge_id, edge in network.get_edges():
        direct = network.get_edge_attribute_value(edge_id, "DIRECT")
        # print(direct)
        if direct:
            if direct == "t":
                network.set_edge_attribute(edge, "DIRECT", "YES")
            else:
                network.set_edge_attribute(edge, "DIRECT", "NO")
                
    # Set prefixes for represents based on the "DATABASE" attribute
    #
    #   Note that this is a good example of a situation that calls
    #   for custom code and does not justify an extension to the load_plan
    #   Cases of this type are too variable. Custom code is easier.
    #
    for node_id, node in network.get_nodes():
        database = network.get_node_attribute_value(node_id, "DATABASE")
        represents = node.get_node_represents()
        if database == "UNIPROT":
            represents = "uniprot:" + represents
            node.set_node_represents(represents)
        if database == "SIGNOR":
            represents = "signor:" + represents
            node.set_node_represents(represents)
        # in all other cases, the identifier is already prefixed
        network.remove_node_attribute(node_id, "DATABASE")

    #=================================
    # POST PROCESS EDGE ATTRIBUTES
    # Rename citation_ids to citation
    #=================================
    for edge_id, edge in network.get_edges():
        cit1 = network.get_edge_attribute_objects(edge_id, "citation_ids")
        if cit1 is not None:
            network.add_edge_attribute(property_of=cit1.get_property_of(), name='citation', 
                                       values=cit1.get_values(), type=cit1.get_data_type())
            network.remove_edge_attribute(edge_id, "citation_ids")
        
        cd = network.get_edge_attribute_objects(edge_id, "CELL_DATA")
        if cd is not None:
            cd_value = cd.get_values()
            cd_split = cd_value.split(';')
            cd.set_values(cd_split)

            cd.set_data_type('list_of_string')

            
        td = network.get_edge_attribute_objects(edge_id, "TISSUE_DATA")
        if td is not None:
            td_value = td.get_values()
            td_split = td_value.split(';')
            td.set_values(td_split)

            td.set_data_type('list_of_string')

        
    print(network.get_summary())
    return network

signor_network = get_signor_network("SIGNOR-MM", load_plan)
#signor_network = get_signor_network("SIGNOR-MonoIL10TR", load_plan)
#print(signor_network.__str__())
# Out:
# Name: Untitled
# Nodes: 30
# Edges: 137
# Node Attributes: 30
# Edge Attributes: 840

# %% [markdown]
# ## Function to Get the Description and Other Info About the Pathway

# %%
def add_pathway_info(network, network_id):
    url = "http://signor.uniroma2.it/getPathwayData.php?pathway=" + str(network_id)#network.get_network_attribute("SIGNOR_ID"))
    print(url)
    response = requests.get(url)
    pathway_info = response.text
    dataframe = pd.read_csv(io.StringIO(pathway_info), sep='\t')
    print(pd.isnull(dataframe.iat[0,1]))
    #print(dataframe)
    if not pd.isnull(dataframe.iat[0, 1]):
        network.set_name(dataframe.iat[0,1])
    if not pd.isnull(dataframe.iat[0, 0]):
        network.set_network_attribute("labels", [dataframe.iat[0, 0]], type='list_of_string')
    if not pd.isnull(dataframe.iat[0, 3]):
        network.set_network_attribute("author", dataframe.iat[0, 3])
    if not pd.isnull(dataframe.iat[0, 2]):
        append_desc = '<p><br/></p><h6><b>Node Legend:</b><br/>Light green oval &gt; Protein/Protein Family<br/>Dark green round rectangle &gt; Complex<br/>Orange octagon &gt; Chemical<br/>Purple octagon &gt; Small molecule<br/>White rectangles &gt; Phenotype<br/>Light blue diamond &gt; Stimulus</h6><h6><b>Edge Legend:</b><br/>Solid &gt; Direct interaction<br/>Dashed &gt; Indirect or Unknown interaction<br/>Blue &gt; Up-regulation<br/>Red &gt; Down-regulation<br/>Black &gt; Form complex or Unknown</h6>'
        network.set_network_attribute("description", '%s %s' % (dataframe.iat[0, 2], append_desc))
        
    network.set_network_attribute('rightsHolder', 'Prof. Gianni Cesareni')
    network.set_network_attribute("rights", "Attribution-ShareAlike 4.0 International (CC BY-SA 4.0)")
    network.set_network_attribute("reference", "<div>Perfetto L., <i>et al.</i></div><div><b>SIGNOR: a database of causal relationships between biological entities</b><i>.</i></div><div>Nucleic Acids Res. 2016 Jan 4;44(D1):D548-54</div><div><span><a href=\"https://doi.org/10.1093/nar/gkv1048\" target=\"\">doi: 10.1093/nar/gkv1048</a></span></div>")    
    network.set_network_attribute('dataSource', 'https://signor.uniroma2.it/pathway_browser.php?organism=&pathway_list=' + str(network_id))
    
    network.set_network_attribute("version", f"{datetime.now():%d-%b-%Y}")
    
    disease_pathways = ['ALZHAIMER DISEASE', 'FSGS', 'NOONAN SYNDROME', 'PARKINSON DISEASE']
    
    cancer_pathways = ['ACUTE MYELOID LEUKEMIA', 'COLORECTAL CARCINOMA', 'GLIOBLASTOMA MULTIFORME', 
                       'LUMINAL BREAST CANCER', 'MALIGNANT MELANOMA', 'PROSTATE CANCER', 
                       'RHABDOMYOSARCOMA', 'THYROID CANCER']
    
    if signor_id_name_mapping.get(network_id).upper() in disease_pathways:
        network.set_network_attribute("networkType", "Disease Pathway")
    elif signor_id_name_mapping.get(network_id).upper() in cancer_pathways:
        network.set_network_attribute("networkType", "Cancer Pathway")
    else:
        network.set_network_attribute("networkType", "Signalling Pathway")
    # TODO: set “networkType” property depending on network
    #    a. Signalling Pathway
    #    b. Disease Pathway
    #    c. Cancer Pathway
    
#add_pathway_info(signor_network, 'SIGNOR-PC')
add_pathway_info(signor_network, 'SIGNOR-MM')
#print(network.get_network_attribute("description"))
print(signor_network.get_network_attribute("Labels"))
# Out:
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-MM
# False
# None

# %% [markdown]
# ## Specify the Network Containing the Visual Style to Apply to the SIGNOR Networks

# %%
# Use the visual properties of network ... to style each output network
# http://www.ndexbio.org/#/network/d3c5ca09-bb42-11e7-94d3-0ac135e8bacf
# cytoscape_visual_properties_template_id = 'f54eaef9-013c-11e8-81c8-06832d634f41'
#cytoscape_visual_properties_template_id = '13c2e3f1-11cc-11e8-b939-0ac135e8bacf' # PUBLIC
cytoscape_visual_properties_template_id = 'cded1818-1c0d-11e8-801d-06832d634f41' # DEV

# %% [markdown]
# ## Function to Apply a Layout to the Network

# %%
def cartesian(G):
    return [{'cartesianLayout': [
        {'node': n, 'x': float(G.pos[n][0]), 'y': float(G.pos[n][1])}
        for n in G.pos
        ]}]

def apply_spring_layout(network):
    my_networkx = network.to_networkx()
    my_networkx.pos = nx.drawing.spring_layout(my_networkx)
    #my_networkx.pos = nx.drawing.circular_layout(my_networkx)
    cartesian_aspect = cartesian(my_networkx)
    network.set_opaque_aspect("cartesianCoordinates", cartesian_aspect)

# %% [markdown]
# ## Function to Print a Sample of Nodes in the Network
# #### (For a Spot-Check when Debugging)

# %%
def spot_check_nodes(network, attribute_name):
    for id, node in itertools.islice(network.get_nodes(), 5):
        attribute_value = my_network.get_node_attribute_value(node, attribute_name)
        print("%s: %s = %s" % (node.get_name(), attribute_name, attribute_value))

# %% [markdown]
# ## Function to Upload the Network

# %%
def upload_signor_network(network, server, username, password, update_uuid=False):
    if update_uuid:
        message = network.update_to(update_uuid, server, username, password)      
    else:
        message = network.upload_to(server, username, password)
    return(message)

# %% [markdown]
# ## Function to Process One Signor Pathway ID

# %%
def process_signor_id(signor_id, cytoscape_visual_properties_template_id, load_plan, server, username, password):
    network = get_signor_network(signor_id, load_plan)
    # print(network.__str__())
    add_pathway_info(network, signor_id)
    # print(network.to_cx())
    network.apply_template(username=username, password=password, server=server,
                           uuid=cytoscape_visual_properties_template_id)
    apply_spring_layout(network)
    network.generate_metadata_aspect()

    if network.node_int_id_generator:
        network.node_id_lookup = list(network.node_int_id_generator)
    network.generate_aspect('nodes')
    network.generate_aspect('edges')
    print(network.get_name())
    network_update_key = update_signor_mapping.get(network.get_name().upper())
    if network_update_key is not None:
        print("updating")
        return upload_signor_network(network, server, username, password, update_uuid=network_update_key)
    else:
        print("new network")
        return upload_signor_network(network, server, username, password)

process_signor_id("SIGNOR-MM", cytoscape_visual_properties_template_id, load_plan, my_server, my_username, my_password)
# Out:
# Name: Untitled
# Nodes: 30
# Edges: 137
# Node Attributes: 30
# Edge Attributes: 840
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-MM
# False
# http://dev.ndexbio.org/v2/network/9811b0f8-1c14-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 1, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'version': '1.0', 'consistencyGroup': 1, 'properties': []}, {'name': 'cartesianCoordinates', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 1, 'properties': []}, {'name': 'nodes', 'elementCount': 32, 'idCounter': 31, 'version': '1.0', 'consistencyGroup': 1, 'properties': []}, {'name': 'edges', 'elementCount': 155, 'idCounter': 154, 'version': '1.0', 'consistencyGroup': 1, 'properties': []}, {'name': '@context', 'elementCount': 1, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 7, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 32, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 982, 'properties': []}]
# http://dev.ndexbio.org/v2/network/9811b0f8-1c14-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/9811b0f8-1c14-11e8-801d-06832d634f41/aspect
# Malignant Melanoma
# updating
# ''

# %% [markdown]
# ## Create a Network Set to Collect the Output Networks

# %%
net_set_url = my_ndex.create_networkset('Signor Networks' + f"{datetime.now():%d-%b-%Y-%s}",#str(datetime.now()), 
                                              'Networks from Signor using data obtained by SIGNOR REST API')
net_set_uuid = net_set_url.split('/')[-1]
print('Network set uuid: ' + net_set_uuid)
# Out:
# Network set uuid: cef584d2-20bb-11e8-9f07-06832d634f41

# %% [markdown]
# ## Process the SIGNOR Pathway IDs

# %%
count = 0
limit = 400
signor_uuids = []
#print(network_id_dataframe)
total_pathways = len(network_id_dataframe['pathway_id'])
for pathway_id in network_id_dataframe['pathway_id']:
    if count >= limit:
        break

    #print(pathway_id)
    print('Processing ' + str(count + 1) + '/' + str(total_pathways))
    upload_message = process_signor_id(pathway_id, cytoscape_visual_properties_template_id,
        load_plan, my_server, my_username, my_password)

    network_update_key = update_signor_mapping.get(signor_id_name_mapping.get(pathway_id).upper())

    if network_update_key is not None:
        signor_uuids.append(network_update_key)
    else:
        network_uuid = upload_message.split('/')[-1]
        signor_uuids.append(network_uuid)

    if limit:
        count += 1

for sig_id in signor_uuids:
    my_ndex.make_network_public(sig_id)

print('Done processing indiviual pathways.')
# Out:
# Processing 1/50
# Name: Untitled
# Nodes: 30
# Edges: 130
# Node Attributes: 30
# Edge Attributes: 858
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-AC
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Adipogenesis
# updating
# Processing 2/50
# Name: Untitled
# Nodes: 33
# Edges: 121
# Node Attributes: 33
# Edge Attributes: 779
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-AD
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Alzheimer Disease
# new network
# Processing 3/50
# Name: Untitled
# Nodes: 44
# Edges: 183
# Node Attributes: 44
# Edge Attributes: 1144
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-AML
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Acute Myeloid Leukemia
# new network
# Processing 4/50
# Name: Untitled
# Nodes: 26
# Edges: 96
# Node Attributes: 26
# Edge Attributes: 615
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-AMPK
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# AMPK Signaling
# updating
# Processing 5/50
# Name: Untitled
# Nodes: 24
# Edges: 34
# Node Attributes: 24
# Edge Attributes: 179
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-Autophagy
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Autophagy
# updating
# Processing 6/50
# Name: Untitled
# Nodes: 29
# Edges: 129
# Node Attributes: 29
# Edge Attributes: 799
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-CRC
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Colorectal Carcinoma
# new network
# Processing 7/50
# Name: Untitled
# Nodes: 18
# Edges: 49
# Node Attributes: 18
# Edge Attributes: 272
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-DR
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Death Receptor Signaling
# updating
# Processing 8/50
# Name: Untitled
# Nodes: 34
# Edges: 116
# Node Attributes: 34
# Edge Attributes: 775
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-EGF
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# EGFR
# updating
# Processing 9/50
# Name: Untitled
# Nodes: 28
# Edges: 112
# Node Attributes: 28
# Edge Attributes: 620
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-FapBMP
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# FAP: BMP
# new network
# Processing 10/50
# Name: Untitled
# Nodes: 8
# Edges: 15
# Node Attributes: 8
# Edge Attributes: 85
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-FapIL4
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# FAP: IL4
# updating
# Processing 11/50
# Name: Untitled
# Nodes: 12
# Edges: 66
# Node Attributes: 12
# Edge Attributes: 374
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-FapINS
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# FAP: insulin-mediated adipogenesis
# updating
# Processing 12/50
# Name: Untitled
# Nodes: 21
# Edges: 27
# Node Attributes: 21
# Edge Attributes: 127
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-FSGS
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# FSGS
# updating
# Processing 13/50
# Name: Untitled
# Nodes: 25
# Edges: 90
# Node Attributes: 25
# Edge Attributes: 595
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-G1-S_trans
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Cell cycle: G1/S phase transition
# updating
# Processing 14/50
# Name: Untitled
# Nodes: 38
# Edges: 151
# Node Attributes: 38
# Edge Attributes: 1013
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-G2-M_trans
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Cell cycle: G2/M phase transition
# updating
# Processing 15/50
# Name: Untitled
# Nodes: 23
# Edges: 130
# Node Attributes: 23
# Edge Attributes: 825
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-GBM
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Glioblastoma Multiforme
# new network
# Processing 16/50
# Name: Untitled
# Nodes: 20
# Edges: 65
# Node Attributes: 20
# Edge Attributes: 388
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-GCR
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Glucocorticoid Receptor
# new network
# Processing 17/50
# Name: Untitled
# Nodes: 18
# Edges: 49
# Node Attributes: 18
# Edge Attributes: 295
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-Hedgehog
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Hedgehog
# updating
# Processing 18/50
# Name: Untitled
# Nodes: 23
# Edges: 80
# Node Attributes: 23
# Edge Attributes: 534
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-HPP
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Hippo Signaling
# updating
# Processing 19/50
# Name: Untitled
# Nodes: 22
# Edges: 39
# Node Attributes: 22
# Edge Attributes: 227
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-IL1R
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# IL1 Receptor
# updating
# Processing 20/50
# Name: Untitled
# Nodes: 21
# Edges: 42
# Node Attributes: 21
# Edge Attributes: 243
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-IL6
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# IL6
# updating
# Processing 21/50
# Name: Untitled
# Nodes: 35
# Edges: 114
# Node Attributes: 35
# Edge Attributes: 769
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-INSR
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Insulin Receptor
# updating
# Processing 22/50
# Name: Untitled
# Nodes: 31
# Edges: 84
# Node Attributes: 31
# Edge Attributes: 509
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-IOA
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Inhibition of Apoptosis
# updating
# Processing 23/50
# Name: Untitled
# Nodes: 32
# Edges: 155
# Node Attributes: 32
# Edge Attributes: 982
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-LBC
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Luminal Breast Cancer
# new network
# Processing 24/50
# Name: Untitled
# Nodes: 26
# Edges: 83
# Node Attributes: 26
# Edge Attributes: 512
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-M1M2
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Macrophage differentiation
# new network
# Processing 25/50
# Name: Untitled
# Nodes: 25
# Edges: 58
# Node Attributes: 25
# Edge Attributes: 316
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-MCAPO
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Mitochondrial Control of Apoptosis
# updating
# Processing 26/50
# Name: Untitled
# Nodes: 30
# Edges: 137
# Node Attributes: 30
# Edge Attributes: 840
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-MM
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Malignant Melanoma
# updating
# Processing 27/50
# Name: Untitled
# Nodes: 34
# Edges: 133
# Node Attributes: 34
# Edge Attributes: 940
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-MS
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# MTOR Signaling
# updating
# Processing 28/50
# Name: Untitled
# Nodes: 6
# Edges: 19
# Node Attributes: 6
# Edge Attributes: 92
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-MyoATR
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Myotubes: atrophy transcriptional regulation
# new network
# Processing 29/50
# Name: Untitled
# Nodes: 36
# Edges: 229
# Node Attributes: 36
# Edge Attributes: 1449
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-Myogenesis
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# IGF and Myogenesis
# new network
# Processing 30/50
# Name: Untitled
# Nodes: 7
# Edges: 7
# Node Attributes: 7
# Edge Attributes: 41
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-NeutroAM
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Neutrophils: adhesion and migration
# new network
# Processing 31/50
# Name: Untitled
# Nodes: 26
# Edges: 49
# Node Attributes: 26
# Edge Attributes: 275
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-NFKBC
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# NF-KB Canonical
# updating
# Processing 32/50
# Name: Untitled
# Nodes: 15
# Edges: 31
# Node Attributes: 15
# Edge Attributes: 191
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-NFKBNC
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# NF-KB Non Canonical
# new network
# Processing 33/50
# Name: Untitled
# Nodes: 20
# Edges: 36
# Node Attributes: 20
# Edge Attributes: 203
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-NOTCH
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# NOTCH Signaling
# new network
# Processing 34/50
# Name: Untitled
# Nodes: 19
# Edges: 54
# Node Attributes: 19
# Edge Attributes: 315
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-NOTCH_Myogenesis
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# NOTCH Signaling and Myogenesis
# new network
# Processing 35/50
# Name: Untitled
# Nodes: 19
# Edges: 105
# Node Attributes: 19
# Edge Attributes: 700
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-NS
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Noonan syndrome
# new network
# Processing 36/50
# Name: Untitled
# Nodes: 31
# Edges: 137
# Node Attributes: 31
# Edge Attributes: 904
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-P38
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# ...
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Parkinson disease
# new network
# Processing 40/50
# Name: Untitled
# Nodes: 22
# Edges: 70
# Node Attributes: 22
# Edge Attributes: 463
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-PI3K/AKT
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# PI3K/AKT
# updating
# Processing 41/50
# Name: Untitled
# Nodes: 39
# Edges: 204
# Node Attributes: 39
# Edge Attributes: 1249
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-RMS
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Rhabdomyosarcoma
# new network
# Processing 42/50
# Name: Untitled
# Nodes: 24
# Edges: 82
# Node Attributes: 24
# Edge Attributes: 531
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-SAPK-JNK
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# SAPK/JNK Signaling
# new network
# Processing 43/50
# Name: Untitled
# Nodes: 10
# Edges: 20
# Node Attributes: 10
# Edge Attributes: 99
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-ScATR
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Satellite: atrophy
# new network
# Processing 44/50
# Name: Untitled
# Nodes: 25
# Edges: 69
# Node Attributes: 25
# Edge Attributes: 419
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-TA
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# TNF alpha
# updating
# Processing 45/50
# Name: Untitled
# Nodes: 29
# Edges: 55
# Node Attributes: 29
# Edge Attributes: 308
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-TC
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Thyroid cancer
# updating
# Processing 46/50
# Name: Untitled
# Nodes: 35
# Edges: 127
# Node Attributes: 35
# Edge Attributes: 835
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-TCA
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# T cell activation
# updating
# Processing 47/50
# Name: Untitled
# Nodes: 27
# Edges: 63
# Node Attributes: 27
# Edge Attributes: 372
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-TGFb
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# TGFbeta Signaling
# updating
# Processing 48/50
# Name: Untitled
# Nodes: 28
# Edges: 81
# Node Attributes: 28
# Edge Attributes: 483
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-TLR
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# Tol like receptors
# updating
# Processing 49/50
# Name: Untitled
# Nodes: 32
# Edges: 75
# Node Attributes: 32
# Edge Attributes: 446
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-WNT
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# WNT Signaling
# updating
# Processing 50/50
# Name: Untitled
# Nodes: 29
# Edges: 85
# Node Attributes: 29
# Edge Attributes: 511
#
# http://signor.uniroma2.it/getPathwayData.php?pathway=SIGNOR-WNT_Myogenesis
# False
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# [{'name': 'provenanceHistory', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': '@context', 'elementCount': 1, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodes', 'elementCount': 217, 'idCounter': 3951, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edges', 'elementCount': 865, 'idCounter': 17045, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'networkAttributes', 'elementCount': 9, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'nodeAttributes', 'elementCount': 217, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'edgeAttributes', 'elementCount': 5895, 'version': '1.0', 'consistencyGroup': 2, 'properties': []}, {'name': 'cyVisualProperties', 'elementCount': 3, 'consistencyGroup': 2, 'properties': []}, {'name': 'cyHiddenAttributes', 'elementCount': 1, 'properties': []}]
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# http://dev.ndexbio.org/v2/network/cded1818-1c0d-11e8-801d-06832d634f41/aspect
# WNT Signaling and Myogenesis
# updating
# Done processing indiviual pathways.

# %%
def process_full_signor(cytoscape_visual_properties_template_id, load_plan, server, username, password):
    processed_uuids = []
    for species_id in species:
        network = get_full_signor_network(load_plan, species_id)

        network.set_name('FULL-' + species_mapping.get(species_id) + ' (' + f"{datetime.now():%d-%b-%Y}" + ')')
        # add_pathway_info(network, signor_id)
        # print(network.to_cx())
        network.apply_template(
            username=username,
            password=password,
            server=server,
            uuid=cytoscape_visual_properties_template_id)
        apply_spring_layout(network)

        network_update_key = update_signor_mapping.get(network.get_name())
        if network_update_key is not None:
            print("updating")
            #return \
            upload_signor_network(network, server, username, password, update_uuid=network_update_key)
            processed_uuids.append(network_update_key)
        else:
            print("new network")
            upload_message = upload_signor_network(network, server, username, password)
            network_uuid = upload_message.split('/')[-1]
            processed_uuids.append(network_uuid)

    for sig_id in processed_uuids:
        my_ndex._make_network_public_indexed(sig_id)

    return ''

def get_full_signor_network(load_plan, species):
    url = "http://signor.uniroma2.it/getData.php?organism=" + species # Human 9606 # mouse 10090 - Rat 10116

    debug_signor = False
    if debug_signor:
        with open('getDataAll.txt', 'r') as tsvfile:
            usecols = ['entitya', 'typea', 'ida', 'databasea', 'entityb', 'typeb', 'idb', 'databaseb', 'effect',
                       'mechanism', 'residue', 'sequence', 'tax_id', 'cell_data', 'tissue_data', 'modulator_complex',
                       'target_complex', 'modificationa', 'modaseq', 'modificationb', 'modbseq', 'pmid',
                       'direct', 'notes', 'annotator', 'sentence', 'signor_id']
            # usecols = ["entitya", "typea", "ida", "entityb", "typeb", "idb", "effect", "mechanism", "residue", "sequence", "tax_id", "cell_data", "tissue_data", "pmid", "direct", "notes", "annotator", "sentence"]
            df = pd.read_csv(tsvfile,
                             dtype=str,
                             na_filter=False,
                             delimiter='\t',
                             engine='python',
                             names=usecols, index_col=False)
            # df = pd.read_csv(tsvfile,delimiter='\t',engine='python',names=header)

            human_dataframe = df[(df["entitya"] != "") & (df["entityb"] != "") & (df["ida"] != "") & (df["idb"] != "")]

            # print(human_dataframe)
    else:
        response = requests.get(url)
        pathway_data = response.text

        usecols = ['entitya', 'typea', 'ida', 'databasea', 'entityb', 'typeb', 'idb', 'databaseb', 'effect',
                   'mechanism', 'residue', 'sequence', 'tax_id', 'cell_data', 'tissue_data', 'modulator_complex',
                   'target_complex', 'modificationa', 'modaseq', 'modificationb', 'modbseq', 'pmid',
                   'direct', 'notes', 'annotator', 'sentence', 'signor_id']

        df = pd.read_csv(io.StringIO(pathway_data),
                                dtype=str,
                                na_filter=False,
                                delimiter='\t',
                                names=usecols,
                                engine='python', index_col=False)
        # names=usecols)

        # print(dataframe)
        # print(dataframe)
        # filter dataframe to remove rows that are not human
        human_dataframe = df[(df["entitya"] != "") & (df["entityb"] != "") & (df["ida"] != "") & (df["idb"] != "")]

    # human_dataframe = pd.read_csv(io.StringIO(pathway_data),
    #            dtype=str,
    #            na_filter=False,
    #            delimiter='\t',
    #            engine='python')
    # names=usecols)

    # upcase column names
    rename = {}
    for column_name in human_dataframe.columns:
        rename[column_name] = column_name.upper()

    human_dataframe = human_dataframe.rename(columns=rename)

    network = t2n.convert_pandas_to_nice_cx_with_load_plan(human_dataframe, load_plan)

    # Fix values for "DIRECT"
    for edge_id, edge in network.get_edges():
        direct = network.get_edge_attribute_value(edge_id, "DIRECT")
        # print(direct)
        if direct:
            if direct == "t":
                network.set_edge_attribute(edge, "DIRECT", "YES")
            else:
                network.set_edge_attribute(edge, "DIRECT", "NO")

    # Set prefixes for represents based on the "DATABASE" attribute
    #
    #   Note that this is a good example of a situation that calls
    #   for custom code and does not justify an extension to the load_plan
    #   Cases of this type are too variable. Custom code is easier.
    #
    for node_id, node in network.get_nodes():
        database = network.get_node_attribute_value(node_id, "DATABASE")
        represents = node.get_node_represents()
        if database == "UNIPROT":
            represents = "uniprot:" + represents
            node.set_node_represents(represents)
        if database == "SIGNOR":
            represents = "signor:" + represents
            node.set_node_represents(represents)
        # in all other cases, the identifier is already prefixed
        network.remove_node_attribute(node_id, "DATABASE")

    # =================================
    # POST PROCESS EDGE ATTRIBUTES
    # Rename citation_ids to citation
    # =================================
    for edge_id, edge in network.get_edges():
        cit1 = network.get_edge_attribute_objects(edge_id, "citation_ids")
        if cit1 is not None:
            network.add_edge_attribute(property_of=cit1.get_property_of(), name='citation',
                                       values=cit1.get_values(), type=cit1.get_data_type())
            network.remove_edge_attribute(edge_id, "citation_ids")

        cd = network.get_edge_attribute_objects(edge_id, "CELL_DATA")
        if cd is not None:
            cd_value = cd.get_values()
            cd_split = cd_value.split(';')
            cd.set_values(cd_split)

            cd.set_data_type('list_of_string')

        td = network.get_edge_attribute_objects(edge_id, "TISSUE_DATA")
        if td is not None:
            td_value = td.get_values()
            td_split = td_value.split(';')
            td.set_values(td_split)

            td.set_data_type('list_of_string')

    template_network = ndex2.create_nice_cx_from_server(server=my_server,
                                                        uuid=cytoscape_visual_properties_template_id,
                                                        username=my_username, password=my_password)

    network.set_network_attribute("labels", template_network.get_network_attribute('labels'))
    network.set_network_attribute("author", template_network.get_network_attribute('author'))
    append_desc = '<p><br/></p><h6><b>Node Legend:</b><br/>Light green oval &gt; Protein/Protein Family<br/>Dark green round rectangle &gt; Complex<br/>Orange octagon &gt; Chemical<br/>Purple octagon &gt; Small molecule<br/>White rectangles &gt; Phenotype<br/>Light blue diamond &gt; Stimulus</h6><h6><b>Edge Legend:</b><br/>Solid &gt; Direct interaction<br/>Dashed &gt; Indirect or Unknown interaction<br/>Blue &gt; Up-regulation<br/>Red &gt; Down-regulation<br/>Black &gt; Form complex or Unknown</h6>'
    network.set_network_attribute('description', 'FULL-' + species_mapping.get(species) + ' SIGNOR pathway ' + append_desc)
    # network.set_network_attribute("rightsHolder", template_network.get_network_attribute('rightsHolder'))
    # network.set_network_attribute("rights", template_network.get_network_attribute('rights'))
    # network.set_network_attribute("reference", template_network.get_network_attribute('reference'))

    network.set_network_attribute("version", f"{datetime.now():%d-%b-%Y}")  # "0.0.1")

    network.set_network_attribute('rightsHolder', 'Prof. Gianni Cesareni')
    network.set_network_attribute("rights", "Attribution-ShareAlike 4.0 International (CC BY-SA 4.0)")
    network.set_network_attribute("reference",
                                  "<div>Perfetto L., <i>et al.</i></div><div><b>SIGNOR: a database of causal relationships between biological entities</b><i>.</i></div><div>Nucleic Acids Res. 2016 Jan 4;44(D1):D548-54</div><div><span><a href=\"https://doi.org/10.1093/nar/gkv1048\" target=\"\">doi: 10.1093/nar/gkv1048</a></span></div>")

    print(network.get_summary())
    return network


print('Starting full SIGNOR pathway.')
process_full_signor(cytoscape_visual_properties_template_id, load_plan, my_server, my_username, my_password)
print('Done processing full SIGNOR pathway.')
